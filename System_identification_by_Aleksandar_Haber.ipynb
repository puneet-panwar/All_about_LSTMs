# %% [markdown]
# <a href="https://colab.research.google.com/github/puneet-panwar/All_about_LSTMs/blob/main/System_identification_by_Aleksandar_Haber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Using Recurrent Neural Networks and Keras/TensorFlow to Learn Input-Output Behaviour of Dynamical Systems by [Aleksandar Haber](https://aleksandarhaber.com/using-recurrent-neural-networks-and-keras-tensorflow-to-learn-input-output-behaviour-of-dynamical-systems/)

# %% [markdown]
# ## **Problem Formulation**
#
# Various dynamical systems, such as robotic arms, oscillators, and even economic systems, can be mathematically described by a linearized state-space model having the following form:
# $$\dot{x}(t) = Ax(t) + Bu(t)$$
# $$y(t) = Cx(t) + Du(t)$$
# The vector **u** represents control inputs acting on the system. The vector **y** is the vector of observed variables, and the vector **x** is a state vector. Loosely speaking, this vector represents the internal system memory.
#
#
# From a practical point of view, it is easier to estimate a discrete-time version of the original system. The discrete-time system has the following form:
# $$x_{k+1} = Ax_k + Bu_k$$
# $$y_k = Cx_k + Du_k$$
#
# k is the discrete-time instant. t = kT, where T is the sampling period.
#
# The standard identification problem for the system can be formulated as follows:
# - Given the sequence of the input-output data $${(u_0, y_0), (u_1, y_1),.....,(u_N, y_N)}$$
# where N is the length of sequence, estimate the system matrices A,B,C,D up to (unknown) similarity transformation.
# - The estimated state-space model should accurately reproduce the input-output behavior of the original system.
# - The goal is to train (learn) the parameters of recurrent neural networks such that trained networks produce the input-output behavior of the discrete-time state-space model. That is, when we apply the sequence of control inputs $${u_0, u_1,...., u_N}$$ along with the initial state of the system to the NN, it should produce the sequence of outputs $$(\hat{y}_0, \hat{y}_1,.....,\hat{y}_N)$$  that accurately approximates the output sequence $$(y_0, y_1,....,y_N)$$ of the real-sytem.
#
# In the sequel, we show how to perform this using the Keras/TensorFlow machine learning toolbox. For presentation clarity, this will be explained using an example of a mass-spring system.

# %% [markdown]
# ![mass_spring-1024x331.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The mathematical model of mass-spring-damper system is given by:
# $$m\ddot{d} + k_d\dot{d} + k_sd = F$$
# where d is the distance from the equilibrium point, m is the mass of the block. By introducing the state-space variables, $$x_1 = d \quad \text{and} \quad x_2 = \dot{d}$$ the model can be written in state-space form:
#
#
# $$\begin{bmatrix} \dot{x}_1 \\ \dot{x}_2 \end{bmatrix} = \begin{bmatrix} 0 & 1 \\ -k_s/m & -k_d/m \end{bmatrix} \begin{bmatrix} x_1 \\ x_2 \end{bmatrix} + \begin{bmatrix} 0 \\ 1/m \end{bmatrix} F$$
# we assume that only the position vector d can be observed. Consequently, the output equation takes the following form:
# $$y = \begin{bmatrix} 1 & 0 \end{bmatrix}x$$
#
# To transform this continuous time-domain model into discrete-time model, we can use *Backward-Euler* method. $$ \frac{x_k - x_{k-1}}{h} = Ax_k + Bu_{k-1} $$
# simplification of this equation leads to:
# $$ x_k = \tilde{A}x_{k-1} + \tilde{B}u_{k-1}$$
# where $$\tilde{A} = (I-hA)^{-1} \quad \text{and} \quad \tilde{B} = h\tilde{A}B $$
# The output equation remails unchanged.
#
# Next, we present a Python code for computing the system response on the basis of the backward Euler method. The code will be used to generate training, validation, and test data for recurrent neural networks.

# %% [markdown]
# Here are a few comments about the code.
# - In lines 6-10. we define the system matrices and the initial condition (a random initial condition).
# - Lines 13-14: we use 300 time steps, and a discretization step (sampling period) of 0.5 seconds.
# Here it should be noted that the discretization step is relatively high, adding additional damping to the system discrete-time system.
# Here we do not care about this phenomenon, and we consider the discrete-time system as a data generating system.
# - In code line 18, we define a step function. Uncomment line 17, if you want to use a random signal as an input.
# - Lines 30-49 define a function that simulates the dynamics and that returns the state and output sequences.

# %%
# !git clone https://github.com/puneet-panwar/All_about_LSTMs
# %cd All_about_LSTMs
# Out:
# Cloning into 'All_about_LSTMs'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 76 (delta 32), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (76/76), done.
# /content/All_about_LSTMs

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# define the continuous-time system matrices
 
A=np.matrix([[0, 1],[- 0.1, -0.05]])
B=np.matrix([[0],[1]])
C=np.matrix([[1, 0]])
#define an initial state for simulation
x0=np.random.rand(2,1)
 
#define the number of time-samples used for the simulation and the sampling time for the discretization
time=300
sampling=0.5
 
#define an input sequence for the simulation
#input_seq=np.random.rand(time,1)
input_seq=np.ones(time)
#plt.plot(input_seq)
 
# the following function simulates the state-space model using the backward Euler method
# the input parameters are:
#    -- A,B,C              - continuous time system matrices 
#    -- initial_state      - the initial state of the system 
#    -- time_steps         - the total number of simulation time steps 
#    -- sampling_perios    - the sampling period for the backward Euler discretization 
# this function returns the state sequence and the output sequence
# they are stored in the vectors Xd and Yd respectively

def simulate(A,B,C,initial_state,input_sequence, time_steps,sampling_period):
    from numpy.linalg import inv
    I=np.identity(A.shape[0]) # this is an identity matrix
    Ad=inv(I-sampling_period*A)
    Bd=Ad*sampling_period*B
    Xd=np.zeros(shape=(A.shape[0],time_steps+1))
    Yd=np.zeros(shape=(C.shape[0],time_steps+1))
     
    for i in range(0,time_steps):
       if i==0:
           Xd[:,[i]]=initial_state
           Yd[:,[i]]=C*initial_state
           x=Ad*initial_state+Bd*input_sequence[i]
       else:
           Xd[:,[i]]=x
           Yd[:,[i]]=C*x
           x=Ad*x+Bd*input_sequence[i]
    Xd[:,[-1]]=x
    Yd[:,[-1]]=C*x
    return Xd, Yd
     
state,output=simulate(A,B,C,x0,input_seq, time ,sampling)    
 
 
plt.plot(output[0,:])
plt.xlabel('Discrete time instant-k')
plt.ylabel('Position- d')
plt.title('System step response')
# Out:
# Text(0.5, 1.0, 'System step response')

# %% [markdown]
# Next, we proceed with training the machine learning models. The following code defines a mass-spring model with arbitrary parameters and defines the discretization steps and the total number of time samples.

# %%
###############################################################################
#                   Model defintion
###############################################################################
 
# First, we need to define the system matrices of the state-space model:
# this is a continuous-time model, we will simulate it using the backward Euler method
A=np.matrix([[0, 1],[- 0.1, -0.000001]])
B=np.matrix([[0],[1]])
C=np.matrix([[1, 0]])
 
#define the number of time samples used for simulation and the discretization step (sampling)
time=200
sampling=0.5

# %% [markdown]
# - To learn the model, we use a random input sequence. Furthermore, we use a random initial condition. Special care needs to be given to the definition of the training, validation, and test data.
#
# - According to the Keras documentation, recurrent neural networks take a tensor input of the following shape: “(batch_size, timesteps, input_features)”. In our case, batch_size=1, timesteps=time+1, and input_features=2.
# If we denote the test input data by “testX”, then the entry “testX[0,:,:]” has the following form: $$textX[0,:,:] = \begin{bmatrix} {x_0}^(1) & {x_0}^(2) \\
# u_0 & 0 \\ u_1 & 0 \\ . & . \\ . & . \\ u_{199} & 0 \end{bmatrix}$$
#
# - First of all, in order to predict the system response, the model needs to “know” the initial state. This is why the first row of the above matrix is equal to the initial state.
#
# - The entries on the first column, starting from the row 2 to the row 201 are the input sequence (the force applied to the model).
#
# - The corresponding entries on the second row are equal to zeros. This has been done in order to keep the sliced tensor dimension constant (Is there a better way to do this?).
#
# - The output, denoted by “output_train” in the code, is defined in the same manner.
# The output shape is (1,201,1).
#
# - The first entry of the sliced output is x_{01} and the remaining entries are equal to the observed output sequence.
#
# - Here for simplicity, we did not scale the training data. It should be emphasized that the inputs and outputs should not be scaled independently since they are related (special attention needs to be dedicated to the scaling or “detrending” problem).

# %% [markdown]
# ## **Training, Validation and test data**
#
# - For training, validation, and test data we use different initial states and input sequences. That is, for randomly generated input sequences and initial conditions, we simulate the system dynamics to obtain three different input-output data sets that are used for training, test, and validation.
#
# - This data is then used to form the input and output tensors. To define the training data, we simulate the system only once.
#
# - This is done because in real-life applications, it is time-consuming to observe the system dynamics for different inputs and initial conditions, and we often can do it only once by performing a single actuation and data collection experiment.
#
# A Python code defining the training, validation, and test datasets, is given below.

# %%
###############################################################################
#                  Create the training data
###############################################################################
#define an input sequence for the simulation
input_seq_train=np.random.rand(time,1)
#define an initial state for simulation
x0_train=np.random.rand(2,1)
 
 
# here we simulate the dynamics
from backward_euler import simulate
state,output_train=simulate(A,B,C,x0_train,input_seq_train, time ,sampling)    
 
output_train=output_train.T
# this is the output data used for training
output_train=np.reshape(output_train,(1,output_train.shape[0],1))
 
input_seq_train=np.reshape(input_seq_train,(input_seq_train.shape[0],1))
tmp_train=np.concatenate((input_seq_train, np.zeros(shape=(input_seq_train.shape[0],1))), axis=1)
tmp_train=np.concatenate((x0_train.T,tmp_train), axis=0)
# this is the input data used for training
trainX=np.reshape(tmp_train, (1,tmp_train.shape[0],tmp_train.shape[1]))
 
###############################################################################
#               Create the validation data
###############################################################################
# new random input sequence
input_seq_validate=np.random.rand(time,1)
# new random initial condition
x0_validate=np.random.rand(2,1)
 
# create a new ouput sequence by simulating the system 
state_validate,output_validate=simulate(A,B,C,x0_validate,input_seq_validate, time ,sampling)    
output_validate=output_validate.T
# this is the output data used for validation
output_validate=np.reshape(output_validate,(1,output_validate.shape[0],1))
 
input_seq_validate=np.reshape(input_seq_validate,(input_seq_validate.shape[0],1))
tmp_validate=np.concatenate((input_seq_validate, np.zeros(shape=(input_seq_validate.shape[0],1))), axis=1)
tmp_validate=np.concatenate((x0_validate.T,tmp_validate), axis=0)
# this is the input data used for validation
validateX=np.reshape(tmp_validate, (1,tmp_validate.shape[0],tmp_validate.shape[1]))
###############################################################################
#               Create the test data
###############################################################################
# new random input sequence
input_seq_test=np.random.rand(time,1)
# new random initial condition
x0_test=np.random.rand(2,1)
 
# create a new ouput sequence by simulating the system 
state_test,output_test=simulate(A,B,C,x0_test,input_seq_test, time ,sampling)    
output_test=output_test.T
# this is the output data used for test
output_test=np.reshape(output_test,(1,output_test.shape[0],1))
 
input_seq_test=np.reshape(input_seq_test,(input_seq_test.shape[0],1))
tmp_test=np.concatenate((input_seq_test, np.zeros(shape=(input_seq_test.shape[0],1))), axis=1)
tmp_test=np.concatenate((x0_test.T,tmp_test), axis=0)
# this is the input data used for test
testX=np.reshape(tmp_test, (1,tmp_test.shape[0],tmp_test.shape[1]))

# %% [markdown]
# ## **Defining the Network**
#
# Next, we define the networks. We will compare three network architectures: SimpleRNN, GRU, and LSTM. For brevity, we do not explain these network architectures.

# %%
# !pip install keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import GRU
from keras.layers import LSTM
from keras.layers import SimpleRNN
from tensorflow.keras.optimizers import RMSprop
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint
 
model=Sequential()
#model.add(SimpleRNN(32, input_shape=(trainX.shape[1],trainX.shape[2]),return_sequences=True))
#model.add(GRU(32, input_shape=(trainX.shape[1],trainX.shape[2]),return_sequences=True))
model.add(LSTM(32, input_shape=(trainX.shape[1],trainX.shape[2]),return_sequences=True))
#model.add(Dense(1))
model.add(TimeDistributed(Dense(1)))  #there is no difference between this and model.add(Dense(1))...
# does not make sense to use metrics=['acc'], see https://stackoverflow.com/questions/41819457/zero-accuracy-training-a-neural-network-in-keras
model.compile(optimizer=RMSprop(), loss='mean_squared_error', metrics=['mse'])
 
 
# after every epoch, we save the model, this is the absolute path on my C: drive, so the path is
# C:\python_files\system_identification\models\
filepath="\\python_files\\system_identification\\models\\weights-{epoch:02d}-{val_loss:.6f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)
callbacks_list = [checkpoint]
history=model.fit(trainX, output_train , epochs=2000, batch_size=1, callbacks=callbacks_list, validation_data=(validateX,output_validate), verbose=2)
 
 
# load the model with the smallest validation loss
#model.load_weights("weights-1997-1.878475.hdf5")
 
# use the test data to predict the model response
testPredict = model.predict(testX)
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.8.0)
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 1/1 - 6s - loss: 29.2975 - mse: 29.2975 - val_loss: 27.5564 - val_mse: 27.5564 - 6s/epoch - 6s/step
# Epoch 2/2000
# 1/1 - 0s - loss: 28.4443 - mse: 28.4443 - val_loss: 26.9988 - val_mse: 26.9988 - 88ms/epoch - 88ms/step
# Epoch 3/2000
# 1/1 - 0s - loss: 27.7992 - mse: 27.7992 - val_loss: 26.4818 - val_mse: 26.4818 - 79ms/epoch - 79ms/step
# Epoch 4/2000
# 1/1 - 0s - loss: 27.1995 - mse: 27.1995 - val_loss: 25.9546 - val_mse: 25.9546 - 90ms/epoch - 90ms/step
# Epoch 5/2000
# 1/1 - 0s - loss: 26.5860 - mse: 26.5860 - val_loss: 25.3760 - val_mse: 25.3760 - 89ms/epoch - 89ms/step
# Epoch 6/2000
# 1/1 - 0s - loss: 25.9107 - mse: 25.9107 - val_loss: 24.7015 - val_mse: 24.7015 - 92ms/epoch - 92ms/step
# Epoch 7/2000
# 1/1 - 0s - loss: 25.1219 - mse: 25.1219 - val_loss: 23.8750 - val_mse: 23.8750 - 79ms/epoch - 79ms/step
# Epoch 8/2000
# 1/1 - 0s - loss: 24.1549 - mse: 24.1549 - val_loss: 22.8137 - val_mse: 22.8137 - 93ms/epoch - 93ms/step
# Epoch 9/2000
# 1/1 - 0s - loss: 22.9193 - mse: 22.9193 - val_loss: 21.4055 - val_mse: 21.4055 - 92ms/epoch - 92ms/step
# Epoch 10/2000
# 1/1 - 0s - loss: 21.3031 - mse: 21.3031 - val_loss: 19.5962 - val_mse: 19.5962 - 80ms/epoch - 80ms/step
# Epoch 11/2000
# 1/1 - 0s - loss: 19.2716 - mse: 19.2716 - val_loss: 17.5863 - val_mse: 17.5863 - 81ms/epoch - 81ms/step
# Epoch 12/2000
# 1/1 - 0s - loss: 17.0461 - mse: 17.0461 - val_loss: 15.7698 - val_mse: 15.7698 - 75ms/epoch - 75ms/step
# Epoch 13/2000
# 1/1 - 0s - loss: 15.0252 - mse: 15.0252 - val_loss: 14.3235 - val_mse: 14.3235 - 99ms/epoch - 99ms/step
# Epoch 14/2000
# 1/1 - 0s - loss: 13.3865 - mse: 13.3865 - val_loss: 13.1855 - val_mse: 13.1855 - 94ms/epoch - 94ms/step
# Epoch 15/2000
# 1/1 - 0s - loss: 12.0745 - mse: 12.0745 - val_loss: 12.2731 - val_mse: 12.2731 - 92ms/epoch - 92ms/step
# Epoch 16/2000
# 1/1 - 0s - loss: 11.0077 - mse: 11.0077 - val_loss: 11.5249 - val_mse: 11.5249 - 82ms/epoch - 82ms/step
# Epoch 17/2000
# 1/1 - 0s - loss: 10.1225 - mse: 10.1225 - val_loss: 10.8989 - val_mse: 10.8989 - 80ms/epoch - 80ms/step
# Epoch 18/2000
# 1/1 - 0s - loss: 9.3744 - mse: 9.3744 - val_loss: 10.3665 - val_mse: 10.3665 - 82ms/epoch - 82ms/step
# Epoch 19/2000
# 1/1 - 0s - loss: 8.7324 - mse: 8.7324 - val_loss: 9.9073 - val_mse: 9.9073 - 93ms/epoch - 93ms/step
# Epoch 20/2000
# 1/1 - 0s - loss: 8.1745 - mse: 8.1745 - val_loss: 9.5066 - val_mse: 9.5066 - 93ms/epoch - 93ms/step
# Epoch 21/2000
# 1/1 - 0s - loss: 7.6842 - mse: 7.6842 - val_loss: 9.1533 - val_mse: 9.1533 - 85ms/epoch - 85ms/step
# Epoch 22/2000
# 1/1 - 0s - loss: 7.2489 - mse: 7.2489 - val_loss: 8.8388 - val_mse: 8.8388 - 91ms/epoch - 91ms/step
# Epoch 23/2000
# 1/1 - 0s - loss: 6.8589 - mse: 6.8589 - val_loss: 8.5565 - val_mse: 8.5565 - 92ms/epoch - 92ms/step
# Epoch 24/2000
# 1/1 - 0s - loss: 6.5064 - mse: 6.5064 - val_loss: 8.3012 - val_mse: 8.3012 - 87ms/epoch - 87ms/step
# Epoch 25/2000
# 1/1 - 0s - loss: 6.1854 - mse: 6.1854 - val_loss: 8.0690 - val_mse: 8.0690 - 91ms/epoch - 91ms/step
# Epoch 26/2000
# 1/1 - 0s - loss: 5.8910 - mse: 5.8910 - val_loss: 7.8565 - val_mse: 7.8565 - 80ms/epoch - 80ms/step
# Epoch 27/2000
# 1/1 - 0s - loss: 5.6193 - mse: 5.6193 - val_loss: 7.6613 - val_mse: 7.6613 - 80ms/epoch - 80ms/step
# Epoch 28/2000
# 1/1 - 0s - loss: 5.3673 - mse: 5.3673 - val_loss: 7.4814 - val_mse: 7.4814 - 90ms/epoch - 90ms/step
# Epoch 29/2000
# 1/1 - 0s - loss: 5.1326 - mse: 5.1326 - val_loss: 7.3155 - val_mse: 7.3155 - 94ms/epoch - 94ms/step
# Epoch 30/2000
# 1/1 - 0s - loss: 4.9134 - mse: 4.9134 - val_loss: 7.1624 - val_mse: 7.1624 - 83ms/epoch - 83ms/step
# Epoch 31/2000
# 1/1 - 0s - loss: 4.7084 - mse: 4.7084 - val_loss: 7.0212 - val_mse: 7.0212 - 109ms/epoch - 109ms/step
# Epoch 32/2000
# 1/1 - 0s - loss: 4.5166 - mse: 4.5166 - val_loss: 6.8914 - val_mse: 6.8914 - 83ms/epoch - 83ms/step
# Epoch 33/2000
# 1/1 - 0s - loss: 4.3372 - mse: 4.3372 - val_loss: 6.7723 - val_mse: 6.7723 - 94ms/epoch - 94ms/step
# Epoch 34/2000
# 1/1 - 0s - loss: 4.1696 - mse: 4.1696 - val_loss: 6.6635 - val_mse: 6.6635 - 91ms/epoch - 91ms/step
# Epoch 35/2000
# 1/1 - 0s - loss: 4.0135 - mse: 4.0135 - val_loss: 6.5647 - val_mse: 6.5647 - 79ms/epoch - 79ms/step
# Epoch 36/2000
# 1/1 - 0s - loss: 3.8684 - mse: 3.8684 - val_loss: 6.4753 - val_mse: 6.4753 - 93ms/epoch - 93ms/step
# Epoch 37/2000
# 1/1 - 0s - loss: 3.7339 - mse: 3.7339 - val_loss: 6.3950 - val_mse: 6.3950 - 80ms/epoch - 80ms/step
# Epoch 38/2000
# 1/1 - 0s - loss: 3.6096 - mse: 3.6096 - val_loss: 6.3233 - val_mse: 6.3233 - 93ms/epoch - 93ms/step
# Epoch 39/2000
# 1/1 - 0s - loss: 3.4953 - mse: 3.4953 - val_loss: 6.2598 - val_mse: 6.2598 - 95ms/epoch - 95ms/step
# Epoch 40/2000
# 1/1 - 0s - loss: 3.3903 - mse: 3.3903 - val_loss: 6.2040 - val_mse: 6.2040 - 83ms/epoch - 83ms/step
# Epoch 41/2000
# 1/1 - 0s - loss: 3.2943 - mse: 3.2943 - val_loss: 6.1554 - val_mse: 6.1554 - 95ms/epoch - 95ms/step
# Epoch 42/2000
# 1/1 - 0s - loss: 3.2069 - mse: 3.2069 - val_loss: 6.1136 - val_mse: 6.1136 - 89ms/epoch - 89ms/step
# Epoch 43/2000
# 1/1 - 0s - loss: 3.1276 - mse: 3.1276 - val_loss: 6.0780 - val_mse: 6.0780 - 85ms/epoch - 85ms/step
# Epoch 44/2000
# 1/1 - 0s - loss: 3.0559 - mse: 3.0559 - val_loss: 6.0482 - val_mse: 6.0482 - 97ms/epoch - 97ms/step
# Epoch 45/2000
# 1/1 - 0s - loss: 2.9915 - mse: 2.9915 - val_loss: 6.0237 - val_mse: 6.0237 - 83ms/epoch - 83ms/step
# Epoch 46/2000
# 1/1 - 0s - loss: 2.9337 - mse: 2.9337 - val_loss: 6.0039 - val_mse: 6.0039 - 85ms/epoch - 85ms/step
# Epoch 47/2000
# 1/1 - 0s - loss: 2.8823 - mse: 2.8823 - val_loss: 5.9884 - val_mse: 5.9884 - 90ms/epoch - 90ms/step
# Epoch 48/2000
# 1/1 - 0s - loss: 2.8367 - mse: 2.8367 - val_loss: 5.9766 - val_mse: 5.9766 - 79ms/epoch - 79ms/step
# Epoch 49/2000
# 1/1 - 0s - loss: 2.7965 - mse: 2.7965 - val_loss: 5.9682 - val_mse: 5.9682 - 89ms/epoch - 89ms/step
# Epoch 50/2000
# 1/1 - 0s - loss: 2.7612 - mse: 2.7612 - val_loss: 5.9626 - val_mse: 5.9626 - 81ms/epoch - 81ms/step
# Epoch 51/2000
# 1/1 - 0s - loss: 2.7304 - mse: 2.7304 - val_loss: 5.9593 - val_mse: 5.9593 - 79ms/epoch - 79ms/step
# Epoch 52/2000
# 1/1 - 0s - loss: 2.7037 - mse: 2.7037 - val_loss: 5.9580 - val_mse: 5.9580 - 83ms/epoch - 83ms/step
# Epoch 53/2000
# 1/1 - 0s - loss: 2.6805 - mse: 2.6805 - val_loss: 5.9583 - val_mse: 5.9583 - 92ms/epoch - 92ms/step
# Epoch 54/2000
# 1/1 - 0s - loss: 2.6607 - mse: 2.6607 - val_loss: 5.9598 - val_mse: 5.9598 - 95ms/epoch - 95ms/step
# Epoch 55/2000
# 1/1 - 0s - loss: 2.6437 - mse: 2.6437 - val_loss: 5.9621 - val_mse: 5.9621 - 97ms/epoch - 97ms/step
# Epoch 56/2000
# 1/1 - 0s - loss: 2.6291 - mse: 2.6291 - val_loss: 5.9649 - val_mse: 5.9649 - 82ms/epoch - 82ms/step
# Epoch 57/2000
# 1/1 - 0s - loss: 2.6168 - mse: 2.6168 - val_loss: 5.9679 - val_mse: 5.9679 - 89ms/epoch - 89ms/step
# Epoch 58/2000
# 1/1 - 0s - loss: 2.6064 - mse: 2.6064 - val_loss: 5.9709 - val_mse: 5.9709 - 81ms/epoch - 81ms/step
# Epoch 59/2000
# 1/1 - 0s - loss: 2.5975 - mse: 2.5975 - val_loss: 5.9737 - val_mse: 5.9737 - 89ms/epoch - 89ms/step
# Epoch 60/2000
# 1/1 - 0s - loss: 2.5900 - mse: 2.5900 - val_loss: 5.9760 - val_mse: 5.9760 - 81ms/epoch - 81ms/step
# Epoch 61/2000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.9777 - val_mse: 5.9777 - 82ms/epoch - 82ms/step
# Epoch 62/2000
# 1/1 - 0s - loss: 2.5780 - mse: 2.5780 - val_loss: 5.9787 - val_mse: 5.9787 - 90ms/epoch - 90ms/step
# Epoch 63/2000
# 1/1 - 0s - loss: 2.5733 - mse: 2.5733 - val_loss: 5.9790 - val_mse: 5.9790 - 82ms/epoch - 82ms/step
# Epoch 64/2000
# 1/1 - 0s - loss: 2.5691 - mse: 2.5691 - val_loss: 5.9786 - val_mse: 5.9786 - 80ms/epoch - 80ms/step
# Epoch 65/2000
# 1/1 - 0s - loss: 2.5654 - mse: 2.5654 - val_loss: 5.9773 - val_mse: 5.9773 - 91ms/epoch - 91ms/step
# Epoch 66/2000
# 1/1 - 0s - loss: 2.5621 - mse: 2.5621 - val_loss: 5.9753 - val_mse: 5.9753 - 88ms/epoch - 88ms/step
# Epoch 67/2000
# 1/1 - 0s - loss: 2.5590 - mse: 2.5590 - val_loss: 5.9727 - val_mse: 5.9727 - 84ms/epoch - 84ms/step
# Epoch 68/2000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.9695 - val_mse: 5.9695 - 88ms/epoch - 88ms/step
# Epoch 69/2000
# 1/1 - 0s - loss: 2.5536 - mse: 2.5536 - val_loss: 5.9657 - val_mse: 5.9657 - 78ms/epoch - 78ms/step
# Epoch 70/2000
# 1/1 - 0s - loss: 2.5512 - mse: 2.5512 - val_loss: 5.9615 - val_mse: 5.9615 - 94ms/epoch - 94ms/step
# Epoch 71/2000
# 1/1 - 0s - loss: 2.5489 - mse: 2.5489 - val_loss: 5.9571 - val_mse: 5.9571 - 92ms/epoch - 92ms/step
# Epoch 72/2000
# 1/1 - 0s - loss: 2.5467 - mse: 2.5467 - val_loss: 5.9523 - val_mse: 5.9523 - 81ms/epoch - 81ms/step
# Epoch 73/2000
# 1/1 - 0s - loss: 2.5446 - mse: 2.5446 - val_loss: 5.9475 - val_mse: 5.9475 - 74ms/epoch - 74ms/step
# Epoch 74/2000
# 1/1 - 0s - loss: 2.5427 - mse: 2.5427 - val_loss: 5.9425 - val_mse: 5.9425 - 76ms/epoch - 76ms/step
# Epoch 75/2000
# 1/1 - 0s - loss: 2.5408 - mse: 2.5408 - val_loss: 5.9375 - val_mse: 5.9375 - 94ms/epoch - 94ms/step
# Epoch 76/2000
# 1/1 - 0s - loss: 2.5390 - mse: 2.5390 - val_loss: 5.9325 - val_mse: 5.9325 - 83ms/epoch - 83ms/step
# Epoch 77/2000
# 1/1 - 0s - loss: 2.5373 - mse: 2.5373 - val_loss: 5.9276 - val_mse: 5.9276 - 98ms/epoch - 98ms/step
# Epoch 78/2000
# 1/1 - 0s - loss: 2.5357 - mse: 2.5357 - val_loss: 5.9228 - val_mse: 5.9228 - 85ms/epoch - 85ms/step
# Epoch 79/2000
# 1/1 - 0s - loss: 2.5342 - mse: 2.5342 - val_loss: 5.9180 - val_mse: 5.9180 - 94ms/epoch - 94ms/step
# Epoch 80/2000
# 1/1 - 0s - loss: 2.5327 - mse: 2.5327 - val_loss: 5.9134 - val_mse: 5.9134 - 82ms/epoch - 82ms/step
# Epoch 81/2000
# 1/1 - 0s - loss: 2.5313 - mse: 2.5313 - val_loss: 5.9090 - val_mse: 5.9090 - 98ms/epoch - 98ms/step
# Epoch 82/2000
# 1/1 - 0s - loss: 2.5300 - mse: 2.5300 - val_loss: 5.9047 - val_mse: 5.9047 - 92ms/epoch - 92ms/step
# Epoch 83/2000
# 1/1 - 0s - loss: 2.5288 - mse: 2.5288 - val_loss: 5.9005 - val_mse: 5.9005 - 89ms/epoch - 89ms/step
# Epoch 84/2000
# 1/1 - 0s - loss: 2.5276 - mse: 2.5276 - val_loss: 5.8964 - val_mse: 5.8964 - 96ms/epoch - 96ms/step
# Epoch 85/2000
# 1/1 - 0s - loss: 2.5265 - mse: 2.5265 - val_loss: 5.8925 - val_mse: 5.8925 - 81ms/epoch - 81ms/step
# Epoch 86/2000
# 1/1 - 0s - loss: 2.5255 - mse: 2.5255 - val_loss: 5.8888 - val_mse: 5.8888 - 88ms/epoch - 88ms/step
# Epoch 87/2000
# 1/1 - 0s - loss: 2.5245 - mse: 2.5245 - val_loss: 5.8852 - val_mse: 5.8852 - 75ms/epoch - 75ms/step
# Epoch 88/2000
# 1/1 - 0s - loss: 2.5236 - mse: 2.5236 - val_loss: 5.8817 - val_mse: 5.8817 - 95ms/epoch - 95ms/step
# Epoch 89/2000
# 1/1 - 0s - loss: 2.5228 - mse: 2.5228 - val_loss: 5.8783 - val_mse: 5.8783 - 82ms/epoch - 82ms/step
# Epoch 90/2000
# 1/1 - 0s - loss: 2.5219 - mse: 2.5219 - val_loss: 5.8751 - val_mse: 5.8751 - 91ms/epoch - 91ms/step
# Epoch 91/2000
# 1/1 - 0s - loss: 2.5212 - mse: 2.5212 - val_loss: 5.8720 - val_mse: 5.8720 - 80ms/epoch - 80ms/step
# Epoch 92/2000
# 1/1 - 0s - loss: 2.5205 - mse: 2.5205 - val_loss: 5.8690 - val_mse: 5.8690 - 82ms/epoch - 82ms/step
# Epoch 93/2000
# 1/1 - 0s - loss: 2.5198 - mse: 2.5198 - val_loss: 5.8661 - val_mse: 5.8661 - 82ms/epoch - 82ms/step
# Epoch 94/2000
# 1/1 - 0s - loss: 2.5192 - mse: 2.5192 - val_loss: 5.8634 - val_mse: 5.8634 - 72ms/epoch - 72ms/step
# Epoch 95/2000
# 1/1 - 0s - loss: 2.5186 - mse: 2.5186 - val_loss: 5.8608 - val_mse: 5.8608 - 83ms/epoch - 83ms/step
# Epoch 96/2000
# 1/1 - 0s - loss: 2.5180 - mse: 2.5180 - val_loss: 5.8582 - val_mse: 5.8582 - 95ms/epoch - 95ms/step
# Epoch 97/2000
# 1/1 - 0s - loss: 2.5175 - mse: 2.5175 - val_loss: 5.8558 - val_mse: 5.8558 - 83ms/epoch - 83ms/step
# Epoch 98/2000
# 1/1 - 0s - loss: 2.5170 - mse: 2.5170 - val_loss: 5.8535 - val_mse: 5.8535 - 82ms/epoch - 82ms/step
# Epoch 99/2000
# 1/1 - 0s - loss: 2.5165 - mse: 2.5165 - val_loss: 5.8513 - val_mse: 5.8513 - 87ms/epoch - 87ms/step
# Epoch 100/2000
# 1/1 - 0s - loss: 2.5161 - mse: 2.5161 - val_loss: 5.8492 - val_mse: 5.8492 - 72ms/epoch - 72ms/step
# Epoch 101/2000
# 1/1 - 0s - loss: 2.5157 - mse: 2.5157 - val_loss: 5.8471 - val_mse: 5.8471 - 81ms/epoch - 81ms/step
# Epoch 102/2000
# 1/1 - 0s - loss: 2.5153 - mse: 2.5153 - val_loss: 5.8452 - val_mse: 5.8452 - 82ms/epoch - 82ms/step
# Epoch 103/2000
# 1/1 - 0s - loss: 2.5149 - mse: 2.5149 - val_loss: 5.8434 - val_mse: 5.8434 - 82ms/epoch - 82ms/step
# Epoch 104/2000
# 1/1 - 0s - loss: 2.5146 - mse: 2.5146 - val_loss: 5.8417 - val_mse: 5.8417 - 80ms/epoch - 80ms/step
# Epoch 105/2000
# 1/1 - 0s - loss: 2.5143 - mse: 2.5143 - val_loss: 5.8400 - val_mse: 5.8400 - 82ms/epoch - 82ms/step
# Epoch 106/2000
# 1/1 - 0s - loss: 2.5140 - mse: 2.5140 - val_loss: 5.8385 - val_mse: 5.8385 - 95ms/epoch - 95ms/step
# Epoch 107/2000
# 1/1 - 0s - loss: 2.5137 - mse: 2.5137 - val_loss: 5.8370 - val_mse: 5.8370 - 73ms/epoch - 73ms/step
# Epoch 108/2000
# 1/1 - 0s - loss: 2.5134 - mse: 2.5134 - val_loss: 5.8356 - val_mse: 5.8356 - 81ms/epoch - 81ms/step
# Epoch 109/2000
# 1/1 - 0s - loss: 2.5131 - mse: 2.5131 - val_loss: 5.8343 - val_mse: 5.8343 - 81ms/epoch - 81ms/step
# Epoch 110/2000
# 1/1 - 0s - loss: 2.5128 - mse: 2.5128 - val_loss: 5.8331 - val_mse: 5.8331 - 86ms/epoch - 86ms/step
# Epoch 111/2000
# 1/1 - 0s - loss: 2.5126 - mse: 2.5126 - val_loss: 5.8319 - val_mse: 5.8319 - 92ms/epoch - 92ms/step
# Epoch 112/2000
# 1/1 - 0s - loss: 2.5123 - mse: 2.5123 - val_loss: 5.8308 - val_mse: 5.8308 - 94ms/epoch - 94ms/step
# Epoch 113/2000
# 1/1 - 0s - loss: 2.5121 - mse: 2.5121 - val_loss: 5.8298 - val_mse: 5.8298 - 84ms/epoch - 84ms/step
# Epoch 114/2000
# 1/1 - 0s - loss: 2.5118 - mse: 2.5118 - val_loss: 5.8289 - val_mse: 5.8289 - 80ms/epoch - 80ms/step
# Epoch 115/2000
# 1/1 - 0s - loss: 2.5116 - mse: 2.5116 - val_loss: 5.8281 - val_mse: 5.8281 - 91ms/epoch - 91ms/step
# Epoch 116/2000
# 1/1 - 0s - loss: 2.5113 - mse: 2.5113 - val_loss: 5.8273 - val_mse: 5.8273 - 94ms/epoch - 94ms/step
# Epoch 117/2000
# 1/1 - 0s - loss: 2.5111 - mse: 2.5111 - val_loss: 5.8265 - val_mse: 5.8265 - 90ms/epoch - 90ms/step
# Epoch 118/2000
# 1/1 - 0s - loss: 2.5108 - mse: 2.5108 - val_loss: 5.8259 - val_mse: 5.8259 - 91ms/epoch - 91ms/step
# Epoch 119/2000
# 1/1 - 0s - loss: 2.5106 - mse: 2.5106 - val_loss: 5.8253 - val_mse: 5.8253 - 80ms/epoch - 80ms/step
# Epoch 120/2000
# 1/1 - 0s - loss: 2.5103 - mse: 2.5103 - val_loss: 5.8246 - val_mse: 5.8246 - 82ms/epoch - 82ms/step
# Epoch 121/2000
# 1/1 - 0s - loss: 2.5100 - mse: 2.5100 - val_loss: 5.8243 - val_mse: 5.8243 - 81ms/epoch - 81ms/step
# Epoch 122/2000
# 1/1 - 0s - loss: 2.5098 - mse: 2.5098 - val_loss: 5.8234 - val_mse: 5.8234 - 100ms/epoch - 100ms/step
# Epoch 123/2000
# 1/1 - 0s - loss: 2.5095 - mse: 2.5095 - val_loss: 5.8241 - val_mse: 5.8241 - 78ms/epoch - 78ms/step
# Epoch 124/2000
# 1/1 - 0s - loss: 2.5092 - mse: 2.5092 - val_loss: 5.8207 - val_mse: 5.8207 - 96ms/epoch - 96ms/step
# Epoch 125/2000
# 1/1 - 0s - loss: 2.5090 - mse: 2.5090 - val_loss: 5.8295 - val_mse: 5.8295 - 81ms/epoch - 81ms/step
# Epoch 126/2000
# 1/1 - 0s - loss: 2.5087 - mse: 2.5087 - val_loss: 5.8009 - val_mse: 5.8009 - 92ms/epoch - 92ms/step
# Epoch 127/2000
# 1/1 - 0s - loss: 2.5091 - mse: 2.5091 - val_loss: 5.8884 - val_mse: 5.8884 - 90ms/epoch - 90ms/step
# Epoch 128/2000
# 1/1 - 0s - loss: 2.5134 - mse: 2.5134 - val_loss: 5.7521 - val_mse: 5.7521 - 85ms/epoch - 85ms/step
# Epoch 129/2000
# 1/1 - 0s - loss: 2.5169 - mse: 2.5169 - val_loss: 5.8745 - val_mse: 5.8745 - 86ms/epoch - 86ms/step
# Epoch 130/2000
# 1/1 - 0s - loss: 2.5113 - mse: 2.5113 - val_loss: 5.7955 - val_mse: 5.7955 - 83ms/epoch - 83ms/step
# Epoch 131/2000
# 1/1 - 0s - loss: 2.5086 - mse: 2.5086 - val_loss: 5.8370 - val_mse: 5.8370 - 82ms/epoch - 82ms/step
# Epoch 132/2000
# 1/1 - 0s - loss: 2.5076 - mse: 2.5076 - val_loss: 5.8113 - val_mse: 5.8113 - 94ms/epoch - 94ms/step
# Epoch 133/2000
# 1/1 - 0s - loss: 2.5072 - mse: 2.5072 - val_loss: 5.8283 - val_mse: 5.8283 - 83ms/epoch - 83ms/step
# Epoch 134/2000
# 1/1 - 0s - loss: 2.5068 - mse: 2.5068 - val_loss: 5.8149 - val_mse: 5.8149 - 100ms/epoch - 100ms/step
# Epoch 135/2000
# 1/1 - 0s - loss: 2.5065 - mse: 2.5065 - val_loss: 5.8262 - val_mse: 5.8262 - 82ms/epoch - 82ms/step
# Epoch 136/2000
# 1/1 - 0s - loss: 2.5062 - mse: 2.5062 - val_loss: 5.8147 - val_mse: 5.8147 - 90ms/epoch - 90ms/step
# Epoch 137/2000
# 1/1 - 0s - loss: 2.5059 - mse: 2.5059 - val_loss: 5.8267 - val_mse: 5.8267 - 80ms/epoch - 80ms/step
# Epoch 138/2000
# 1/1 - 0s - loss: 2.5056 - mse: 2.5056 - val_loss: 5.8112 - val_mse: 5.8112 - 92ms/epoch - 92ms/step
# Epoch 139/2000
# 1/1 - 0s - loss: 2.5052 - mse: 2.5052 - val_loss: 5.8315 - val_mse: 5.8315 - 81ms/epoch - 81ms/step
# Epoch 140/2000
# 1/1 - 0s - loss: 2.5049 - mse: 2.5049 - val_loss: 5.8000 - val_mse: 5.8000 - 92ms/epoch - 92ms/step
# Epoch 141/2000
# 1/1 - 0s - loss: 2.5048 - mse: 2.5048 - val_loss: 5.8500 - val_mse: 5.8500 - 80ms/epoch - 80ms/step
# Epoch 142/2000
# 1/1 - 0s - loss: 2.5051 - mse: 2.5051 - val_loss: 5.7734 - val_mse: 5.7734 - 84ms/epoch - 84ms/step
# Epoch 143/2000
# 1/1 - 0s - loss: 2.5064 - mse: 2.5064 - val_loss: 5.8772 - val_mse: 5.8772 - 85ms/epoch - 85ms/step
# Epoch 144/2000
# 1/1 - 0s - loss: 2.5074 - mse: 2.5074 - val_loss: 5.7689 - val_mse: 5.7689 - 83ms/epoch - 83ms/step
# Epoch 145/2000
# 1/1 - 0s - loss: 2.5061 - mse: 2.5061 - val_loss: 5.8564 - val_mse: 5.8564 - 97ms/epoch - 97ms/step
# Epoch 146/2000
# 1/1 - 0s - loss: 2.5041 - mse: 2.5041 - val_loss: 5.7842 - val_mse: 5.7842 - 79ms/epoch - 79ms/step
# Epoch 147/2000
# 1/1 - 0s - loss: 2.5024 - mse: 2.5024 - val_loss: 5.8382 - val_mse: 5.8382 - 92ms/epoch - 92ms/step
# Epoch 148/2000
# 1/1 - 0s - loss: 2.5011 - mse: 2.5011 - val_loss: 5.7872 - val_mse: 5.7872 - 98ms/epoch - 98ms/step
# Epoch 149/2000
# 1/1 - 0s - loss: 2.5001 - mse: 2.5001 - val_loss: 5.8348 - val_mse: 5.8348 - 100ms/epoch - 100ms/step
# Epoch 150/2000
# 1/1 - 0s - loss: 2.4992 - mse: 2.4992 - val_loss: 5.7779 - val_mse: 5.7779 - 98ms/epoch - 98ms/step
# Epoch 151/2000
# 1/1 - 0s - loss: 2.4985 - mse: 2.4985 - val_loss: 5.8448 - val_mse: 5.8448 - 103ms/epoch - 103ms/step
# Epoch 152/2000
# 1/1 - 0s - loss: 2.4980 - mse: 2.4980 - val_loss: 5.7581 - val_mse: 5.7581 - 92ms/epoch - 92ms/step
# Epoch 153/2000
# 1/1 - 0s - loss: 2.4981 - mse: 2.4981 - val_loss: 5.8606 - val_mse: 5.8606 - 87ms/epoch - 87ms/step
# Epoch 154/2000
# 1/1 - 0s - loss: 2.4981 - mse: 2.4981 - val_loss: 5.7477 - val_mse: 5.7477 - 96ms/epoch - 96ms/step
# Epoch 155/2000
# 1/1 - 0s - loss: 2.4970 - mse: 2.4970 - val_loss: 5.8520 - val_mse: 5.8520 - 92ms/epoch - 92ms/step
# Epoch 156/2000
# 1/1 - 0s - loss: 2.4951 - mse: 2.4951 - val_loss: 5.7498 - val_mse: 5.7498 - 74ms/epoch - 74ms/step
# Epoch 157/2000
# 1/1 - 0s - loss: 2.4929 - mse: 2.4929 - val_loss: 5.8396 - val_mse: 5.8396 - 93ms/epoch - 93ms/step
# Epoch 158/2000
# 1/1 - 0s - loss: 2.4909 - mse: 2.4909 - val_loss: 5.7427 - val_mse: 5.7427 - 92ms/epoch - 92ms/step
# Epoch 159/2000
# 1/1 - 0s - loss: 2.4894 - mse: 2.4894 - val_loss: 5.8434 - val_mse: 5.8434 - 101ms/epoch - 101ms/step
# Epoch 160/2000
# 1/1 - 0s - loss: 2.4885 - mse: 2.4885 - val_loss: 5.7244 - val_mse: 5.7244 - 79ms/epoch - 79ms/step
# Epoch 161/2000
# 1/1 - 0s - loss: 2.4881 - mse: 2.4881 - val_loss: 5.8527 - val_mse: 5.8527 - 79ms/epoch - 79ms/step
# Epoch 162/2000
# 1/1 - 0s - loss: 2.4873 - mse: 2.4873 - val_loss: 5.7128 - val_mse: 5.7128 - 82ms/epoch - 82ms/step
# Epoch 163/2000
# 1/1 - 0s - loss: 2.4859 - mse: 2.4859 - val_loss: 5.8426 - val_mse: 5.8426 - 97ms/epoch - 97ms/step
# Epoch 164/2000
# 1/1 - 0s - loss: 2.4829 - mse: 2.4829 - val_loss: 5.7059 - val_mse: 5.7059 - 98ms/epoch - 98ms/step
# Epoch 165/2000
# 1/1 - 0s - loss: 2.4802 - mse: 2.4802 - val_loss: 5.8303 - val_mse: 5.8303 - 93ms/epoch - 93ms/step
# Epoch 166/2000
# 1/1 - 0s - loss: 2.4767 - mse: 2.4767 - val_loss: 5.6772 - val_mse: 5.6772 - 85ms/epoch - 85ms/step
# Epoch 167/2000
# 1/1 - 0s - loss: 2.4726 - mse: 2.4726 - val_loss: 5.8135 - val_mse: 5.8135 - 81ms/epoch - 81ms/step
# Epoch 168/2000
# 1/1 - 0s - loss: 2.4657 - mse: 2.4657 - val_loss: 5.6196 - val_mse: 5.6196 - 82ms/epoch - 82ms/step
# Epoch 169/2000
# 1/1 - 0s - loss: 2.4585 - mse: 2.4585 - val_loss: 5.7911 - val_mse: 5.7911 - 83ms/epoch - 83ms/step
# Epoch 170/2000
# 1/1 - 0s - loss: 2.4476 - mse: 2.4476 - val_loss: 5.5749 - val_mse: 5.5749 - 88ms/epoch - 88ms/step
# Epoch 171/2000
# 1/1 - 0s - loss: 2.4490 - mse: 2.4490 - val_loss: 5.7759 - val_mse: 5.7759 - 91ms/epoch - 91ms/step
# Epoch 172/2000
# 1/1 - 0s - loss: 2.4360 - mse: 2.4360 - val_loss: 5.5481 - val_mse: 5.5481 - 80ms/epoch - 80ms/step
# Epoch 173/2000
# 1/1 - 0s - loss: 2.4174 - mse: 2.4174 - val_loss: 5.6863 - val_mse: 5.6863 - 81ms/epoch - 81ms/step
# Epoch 174/2000
# 1/1 - 0s - loss: 2.3972 - mse: 2.3972 - val_loss: 5.4956 - val_mse: 5.4956 - 91ms/epoch - 91ms/step
# Epoch 175/2000
# 1/1 - 0s - loss: 2.3877 - mse: 2.3877 - val_loss: 5.6456 - val_mse: 5.6456 - 79ms/epoch - 79ms/step
# Epoch 176/2000
# 1/1 - 0s - loss: 2.3708 - mse: 2.3708 - val_loss: 5.3976 - val_mse: 5.3976 - 74ms/epoch - 74ms/step
# Epoch 177/2000
# 1/1 - 0s - loss: 2.3670 - mse: 2.3670 - val_loss: 5.6010 - val_mse: 5.6010 - 84ms/epoch - 84ms/step
# Epoch 178/2000
# 1/1 - 0s - loss: 2.3340 - mse: 2.3340 - val_loss: 5.2770 - val_mse: 5.2770 - 83ms/epoch - 83ms/step
# Epoch 179/2000
# 1/1 - 0s - loss: 2.3065 - mse: 2.3065 - val_loss: 5.4417 - val_mse: 5.4417 - 82ms/epoch - 82ms/step
# Epoch 180/2000
# 1/1 - 0s - loss: 2.2513 - mse: 2.2513 - val_loss: 5.1321 - val_mse: 5.1321 - 92ms/epoch - 92ms/step
# Epoch 181/2000
# 1/1 - 0s - loss: 2.1938 - mse: 2.1938 - val_loss: 5.3398 - val_mse: 5.3398 - 85ms/epoch - 85ms/step
# Epoch 182/2000
# 1/1 - 0s - loss: 2.1286 - mse: 2.1286 - val_loss: 5.1393 - val_mse: 5.1393 - 81ms/epoch - 81ms/step
# Epoch 183/2000
# 1/1 - 0s - loss: 2.1255 - mse: 2.1255 - val_loss: 5.0282 - val_mse: 5.0282 - 87ms/epoch - 87ms/step
# Epoch 184/2000
# 1/1 - 0s - loss: 2.1775 - mse: 2.1775 - val_loss: 5.7307 - val_mse: 5.7307 - 93ms/epoch - 93ms/step
# Epoch 185/2000
# 1/1 - 0s - loss: 1.8949 - mse: 1.8949 - val_loss: 4.5441 - val_mse: 4.5441 - 77ms/epoch - 77ms/step
# Epoch 186/2000
# 1/1 - 0s - loss: 2.2821 - mse: 2.2821 - val_loss: 5.8760 - val_mse: 5.8760 - 81ms/epoch - 81ms/step
# Epoch 187/2000
# 1/1 - 0s - loss: 2.4481 - mse: 2.4481 - val_loss: 5.5951 - val_mse: 5.5951 - 80ms/epoch - 80ms/step
# Epoch 188/2000
# 1/1 - 0s - loss: 2.3662 - mse: 2.3662 - val_loss: 5.6754 - val_mse: 5.6754 - 83ms/epoch - 83ms/step
# Epoch 189/2000
# 1/1 - 0s - loss: 2.1902 - mse: 2.1902 - val_loss: 5.1091 - val_mse: 5.1091 - 87ms/epoch - 87ms/step
# Epoch 190/2000
# 1/1 - 0s - loss: 1.9522 - mse: 1.9522 - val_loss: 5.2131 - val_mse: 5.2131 - 81ms/epoch - 81ms/step
# Epoch 191/2000
# 1/1 - 0s - loss: 2.0176 - mse: 2.0176 - val_loss: 5.3261 - val_mse: 5.3261 - 79ms/epoch - 79ms/step
# Epoch 192/2000
# 1/1 - 0s - loss: 1.7976 - mse: 1.7976 - val_loss: 5.5024 - val_mse: 5.5024 - 87ms/epoch - 87ms/step
# Epoch 193/2000
# 1/1 - 0s - loss: 1.7261 - mse: 1.7261 - val_loss: 5.8405 - val_mse: 5.8405 - 83ms/epoch - 83ms/step
# Epoch 194/2000
# 1/1 - 0s - loss: 1.7507 - mse: 1.7507 - val_loss: 4.1684 - val_mse: 4.1684 - 85ms/epoch - 85ms/step
# Epoch 195/2000
# 1/1 - 0s - loss: 2.3409 - mse: 2.3409 - val_loss: 4.8305 - val_mse: 4.8305 - 99ms/epoch - 99ms/step
# Epoch 196/2000
# 1/1 - 0s - loss: 2.2179 - mse: 2.2179 - val_loss: 4.6034 - val_mse: 4.6034 - 92ms/epoch - 92ms/step
# Epoch 197/2000
# 1/1 - 0s - loss: 1.9601 - mse: 1.9601 - val_loss: 4.5273 - val_mse: 4.5273 - 85ms/epoch - 85ms/step
# Epoch 198/2000
# 1/1 - 0s - loss: 1.7490 - mse: 1.7490 - val_loss: 4.9506 - val_mse: 4.9506 - 68ms/epoch - 68ms/step
# Epoch 199/2000
# 1/1 - 0s - loss: 1.7357 - mse: 1.7357 - val_loss: 4.6567 - val_mse: 4.6567 - 93ms/epoch - 93ms/step
# Epoch 200/2000
# 1/1 - 0s - loss: 2.2464 - mse: 2.2464 - val_loss: 4.6130 - val_mse: 4.6130 - 92ms/epoch - 92ms/step
# Epoch 201/2000
# 1/1 - 0s - loss: 2.1081 - mse: 2.1081 - val_loss: 4.3794 - val_mse: 4.3794 - 81ms/epoch - 81ms/step
# Epoch 202/2000
# 1/1 - 0s - loss: 1.9815 - mse: 1.9815 - val_loss: 4.0085 - val_mse: 4.0085 - 86ms/epoch - 86ms/step
# Epoch 203/2000
# 1/1 - 0s - loss: 1.8059 - mse: 1.8059 - val_loss: 3.5402 - val_mse: 3.5402 - 81ms/epoch - 81ms/step
# Epoch 204/2000
# 1/1 - 0s - loss: 1.6133 - mse: 1.6133 - val_loss: 3.5102 - val_mse: 3.5102 - 81ms/epoch - 81ms/step
# Epoch 205/2000
# 1/1 - 0s - loss: 1.5113 - mse: 1.5113 - val_loss: 4.0021 - val_mse: 4.0021 - 97ms/epoch - 97ms/step
# Epoch 206/2000
# 1/1 - 0s - loss: 2.0280 - mse: 2.0280 - val_loss: 4.7381 - val_mse: 4.7381 - 93ms/epoch - 93ms/step
# Epoch 207/2000
# 1/1 - 0s - loss: 1.8523 - mse: 1.8523 - val_loss: 4.5384 - val_mse: 4.5384 - 91ms/epoch - 91ms/step
# Epoch 208/2000
# 1/1 - 0s - loss: 1.7236 - mse: 1.7236 - val_loss: 4.4067 - val_mse: 4.4067 - 105ms/epoch - 105ms/step
# Epoch 209/2000
# 1/1 - 0s - loss: 1.5354 - mse: 1.5354 - val_loss: 3.8735 - val_mse: 3.8735 - 83ms/epoch - 83ms/step
# Epoch 210/2000
# 1/1 - 0s - loss: 1.3165 - mse: 1.3165 - val_loss: 4.4216 - val_mse: 4.4216 - 81ms/epoch - 81ms/step
# Epoch 211/2000
# 1/1 - 0s - loss: 1.5505 - mse: 1.5505 - val_loss: 3.7292 - val_mse: 3.7292 - 98ms/epoch - 98ms/step
# Epoch 212/2000
# 1/1 - 0s - loss: 1.5992 - mse: 1.5992 - val_loss: 3.4295 - val_mse: 3.4295 - 91ms/epoch - 91ms/step
# Epoch 213/2000
# 1/1 - 0s - loss: 1.3422 - mse: 1.3422 - val_loss: 3.2912 - val_mse: 3.2912 - 82ms/epoch - 82ms/step
# Epoch 214/2000
# 1/1 - 0s - loss: 2.0515 - mse: 2.0515 - val_loss: 4.5308 - val_mse: 4.5308 - 81ms/epoch - 81ms/step
# Epoch 215/2000
# 1/1 - 0s - loss: 2.1897 - mse: 2.1897 - val_loss: 4.0023 - val_mse: 4.0023 - 80ms/epoch - 80ms/step
# Epoch 216/2000
# 1/1 - 0s - loss: 1.5593 - mse: 1.5593 - val_loss: 3.5954 - val_mse: 3.5954 - 79ms/epoch - 79ms/step
# Epoch 217/2000
# 1/1 - 0s - loss: 1.2918 - mse: 1.2918 - val_loss: 3.4836 - val_mse: 3.4836 - 93ms/epoch - 93ms/step
# Epoch 218/2000
# 1/1 - 0s - loss: 1.2232 - mse: 1.2232 - val_loss: 3.4575 - val_mse: 3.4575 - 92ms/epoch - 92ms/step
# Epoch 219/2000
# 1/1 - 0s - loss: 1.3154 - mse: 1.3154 - val_loss: 3.2071 - val_mse: 3.2071 - 90ms/epoch - 90ms/step
# Epoch 220/2000
# 1/1 - 0s - loss: 1.2348 - mse: 1.2348 - val_loss: 3.5379 - val_mse: 3.5379 - 81ms/epoch - 81ms/step
# Epoch 221/2000
# 1/1 - 0s - loss: 1.3990 - mse: 1.3990 - val_loss: 3.1806 - val_mse: 3.1806 - 93ms/epoch - 93ms/step
# Epoch 222/2000
# 1/1 - 0s - loss: 1.1336 - mse: 1.1336 - val_loss: 3.2955 - val_mse: 3.2955 - 79ms/epoch - 79ms/step
# Epoch 223/2000
# 1/1 - 0s - loss: 1.1487 - mse: 1.1487 - val_loss: 3.0591 - val_mse: 3.0591 - 94ms/epoch - 94ms/step
# Epoch 224/2000
# 1/1 - 0s - loss: 1.0651 - mse: 1.0651 - val_loss: 3.3048 - val_mse: 3.3048 - 93ms/epoch - 93ms/step
# Epoch 225/2000
# 1/1 - 0s - loss: 1.1550 - mse: 1.1550 - val_loss: 3.1164 - val_mse: 3.1164 - 80ms/epoch - 80ms/step
# Epoch 226/2000
# 1/1 - 0s - loss: 1.1324 - mse: 1.1324 - val_loss: 3.3366 - val_mse: 3.3366 - 81ms/epoch - 81ms/step
# Epoch 227/2000
# 1/1 - 0s - loss: 1.2559 - mse: 1.2559 - val_loss: 3.1697 - val_mse: 3.1697 - 82ms/epoch - 82ms/step
# Epoch 228/2000
# 1/1 - 0s - loss: 1.0616 - mse: 1.0616 - val_loss: 3.2217 - val_mse: 3.2217 - 82ms/epoch - 82ms/step
# Epoch 229/2000
# 1/1 - 0s - loss: 1.0535 - mse: 1.0535 - val_loss: 2.9234 - val_mse: 2.9234 - 80ms/epoch - 80ms/step
# Epoch 230/2000
# 1/1 - 0s - loss: 1.0441 - mse: 1.0441 - val_loss: 3.3575 - val_mse: 3.3575 - 92ms/epoch - 92ms/step
# Epoch 231/2000
# 1/1 - 0s - loss: 1.0779 - mse: 1.0779 - val_loss: 3.5320 - val_mse: 3.5320 - 81ms/epoch - 81ms/step
# Epoch 232/2000
# 1/1 - 0s - loss: 1.1100 - mse: 1.1100 - val_loss: 2.9967 - val_mse: 2.9967 - 81ms/epoch - 81ms/step
# Epoch 233/2000
# 1/1 - 0s - loss: 1.0003 - mse: 1.0003 - val_loss: 2.5622 - val_mse: 2.5622 - 81ms/epoch - 81ms/step
# Epoch 234/2000
# 1/1 - 0s - loss: 1.0229 - mse: 1.0229 - val_loss: 4.4473 - val_mse: 4.4473 - 89ms/epoch - 89ms/step
# Epoch 235/2000
# 1/1 - 0s - loss: 1.6608 - mse: 1.6608 - val_loss: 4.3722 - val_mse: 4.3722 - 98ms/epoch - 98ms/step
# Epoch 236/2000
# 1/1 - 0s - loss: 1.4996 - mse: 1.4996 - val_loss: 3.6381 - val_mse: 3.6381 - 82ms/epoch - 82ms/step
# Epoch 237/2000
# 1/1 - 0s - loss: 1.3226 - mse: 1.3226 - val_loss: 3.1953 - val_mse: 3.1953 - 81ms/epoch - 81ms/step
# Epoch 238/2000
# 1/1 - 0s - loss: 0.8786 - mse: 0.8786 - val_loss: 3.1208 - val_mse: 3.1208 - 91ms/epoch - 91ms/step
# Epoch 239/2000
# 1/1 - 0s - loss: 0.7850 - mse: 0.7850 - val_loss: 2.7944 - val_mse: 2.7944 - 93ms/epoch - 93ms/step
# Epoch 240/2000
# 1/1 - 0s - loss: 0.7684 - mse: 0.7684 - val_loss: 3.1680 - val_mse: 3.1680 - 94ms/epoch - 94ms/step
# Epoch 241/2000
# 1/1 - 0s - loss: 0.7862 - mse: 0.7862 - val_loss: 2.7452 - val_mse: 2.7452 - 99ms/epoch - 99ms/step
# Epoch 242/2000
# 1/1 - 0s - loss: 0.8961 - mse: 0.8961 - val_loss: 3.5037 - val_mse: 3.5037 - 73ms/epoch - 73ms/step
# Epoch 243/2000
# 1/1 - 0s - loss: 1.1342 - mse: 1.1342 - val_loss: 3.5701 - val_mse: 3.5701 - 81ms/epoch - 81ms/step
# Epoch 244/2000
# 1/1 - 0s - loss: 1.1341 - mse: 1.1341 - val_loss: 2.9337 - val_mse: 2.9337 - 81ms/epoch - 81ms/step
# Epoch 245/2000
# 1/1 - 0s - loss: 0.9943 - mse: 0.9943 - val_loss: 2.7751 - val_mse: 2.7751 - 79ms/epoch - 79ms/step
# Epoch 246/2000
# 1/1 - 0s - loss: 0.7208 - mse: 0.7208 - val_loss: 3.3965 - val_mse: 3.3965 - 77ms/epoch - 77ms/step
# Epoch 247/2000
# 1/1 - 0s - loss: 0.7875 - mse: 0.7875 - val_loss: 2.8799 - val_mse: 2.8799 - 89ms/epoch - 89ms/step
# Epoch 248/2000
# 1/1 - 0s - loss: 1.0445 - mse: 1.0445 - val_loss: 3.3085 - val_mse: 3.3085 - 79ms/epoch - 79ms/step
# Epoch 249/2000
# 1/1 - 0s - loss: 1.0440 - mse: 1.0440 - val_loss: 3.9570 - val_mse: 3.9570 - 79ms/epoch - 79ms/step
# Epoch 250/2000
# 1/1 - 0s - loss: 1.1455 - mse: 1.1455 - val_loss: 2.8501 - val_mse: 2.8501 - 88ms/epoch - 88ms/step
# Epoch 251/2000
# 1/1 - 0s - loss: 0.7116 - mse: 0.7116 - val_loss: 2.5842 - val_mse: 2.5842 - 81ms/epoch - 81ms/step
# Epoch 252/2000
# 1/1 - 0s - loss: 0.7220 - mse: 0.7220 - val_loss: 3.4907 - val_mse: 3.4907 - 90ms/epoch - 90ms/step
# Epoch 253/2000
# 1/1 - 0s - loss: 0.9128 - mse: 0.9128 - val_loss: 3.9028 - val_mse: 3.9028 - 81ms/epoch - 81ms/step
# Epoch 254/2000
# 1/1 - 0s - loss: 1.1289 - mse: 1.1289 - val_loss: 3.1853 - val_mse: 3.1853 - 86ms/epoch - 86ms/step
# Epoch 255/2000
# 1/1 - 0s - loss: 1.0900 - mse: 1.0900 - val_loss: 3.3890 - val_mse: 3.3890 - 92ms/epoch - 92ms/step
# Epoch 256/2000
# 1/1 - 0s - loss: 0.8753 - mse: 0.8753 - val_loss: 3.0269 - val_mse: 3.0269 - 81ms/epoch - 81ms/step
# Epoch 257/2000
# 1/1 - 0s - loss: 0.7018 - mse: 0.7018 - val_loss: 2.6307 - val_mse: 2.6307 - 85ms/epoch - 85ms/step
# Epoch 258/2000
# 1/1 - 0s - loss: 0.7830 - mse: 0.7830 - val_loss: 3.1841 - val_mse: 3.1841 - 81ms/epoch - 81ms/step
# Epoch 259/2000
# 1/1 - 0s - loss: 0.8769 - mse: 0.8769 - val_loss: 3.7937 - val_mse: 3.7937 - 92ms/epoch - 92ms/step
# Epoch 260/2000
# 1/1 - 0s - loss: 0.9733 - mse: 0.9733 - val_loss: 2.6214 - val_mse: 2.6214 - 91ms/epoch - 91ms/step
# Epoch 261/2000
# 1/1 - 0s - loss: 0.7248 - mse: 0.7248 - val_loss: 2.3816 - val_mse: 2.3816 - 85ms/epoch - 85ms/step
# Epoch 262/2000
# 1/1 - 0s - loss: 0.6943 - mse: 0.6943 - val_loss: 4.1121 - val_mse: 4.1121 - 77ms/epoch - 77ms/step
# Epoch 263/2000
# 1/1 - 0s - loss: 1.0581 - mse: 1.0581 - val_loss: 5.2819 - val_mse: 5.2819 - 92ms/epoch - 92ms/step
# Epoch 264/2000
# 1/1 - 0s - loss: 1.2742 - mse: 1.2742 - val_loss: 2.7050 - val_mse: 2.7050 - 92ms/epoch - 92ms/step
# Epoch 265/2000
# 1/1 - 0s - loss: 0.7405 - mse: 0.7405 - val_loss: 2.8365 - val_mse: 2.8365 - 87ms/epoch - 87ms/step
# Epoch 266/2000
# 1/1 - 0s - loss: 0.5789 - mse: 0.5789 - val_loss: 2.6948 - val_mse: 2.6948 - 78ms/epoch - 78ms/step
# Epoch 267/2000
# 1/1 - 0s - loss: 0.5485 - mse: 0.5485 - val_loss: 2.7469 - val_mse: 2.7469 - 91ms/epoch - 91ms/step
# Epoch 268/2000
# 1/1 - 0s - loss: 0.5317 - mse: 0.5317 - val_loss: 2.4674 - val_mse: 2.4674 - 87ms/epoch - 87ms/step
# Epoch 269/2000
# 1/1 - 0s - loss: 0.5279 - mse: 0.5279 - val_loss: 2.9632 - val_mse: 2.9632 - 92ms/epoch - 92ms/step
# Epoch 270/2000
# 1/1 - 0s - loss: 0.5895 - mse: 0.5895 - val_loss: 2.8588 - val_mse: 2.8588 - 89ms/epoch - 89ms/step
# Epoch 271/2000
# 1/1 - 0s - loss: 0.9703 - mse: 0.9703 - val_loss: 3.1197 - val_mse: 3.1197 - 91ms/epoch - 91ms/step
# Epoch 272/2000
# 1/1 - 0s - loss: 1.3037 - mse: 1.3037 - val_loss: 4.9707 - val_mse: 4.9707 - 86ms/epoch - 86ms/step
# Epoch 273/2000
# 1/1 - 0s - loss: 1.9339 - mse: 1.9339 - val_loss: 3.8947 - val_mse: 3.8947 - 92ms/epoch - 92ms/step
# Epoch 274/2000
# 1/1 - 0s - loss: 0.9483 - mse: 0.9483 - val_loss: 2.7783 - val_mse: 2.7783 - 87ms/epoch - 87ms/step
# Epoch 275/2000
# 1/1 - 0s - loss: 0.6291 - mse: 0.6291 - val_loss: 2.7406 - val_mse: 2.7406 - 75ms/epoch - 75ms/step
# Epoch 276/2000
# 1/1 - 0s - loss: 0.5651 - mse: 0.5651 - val_loss: 2.6338 - val_mse: 2.6338 - 81ms/epoch - 81ms/step
# Epoch 277/2000
# 1/1 - 0s - loss: 0.5496 - mse: 0.5496 - val_loss: 2.5593 - val_mse: 2.5593 - 91ms/epoch - 91ms/step
# Epoch 278/2000
# 1/1 - 0s - loss: 0.6674 - mse: 0.6674 - val_loss: 2.9697 - val_mse: 2.9697 - 92ms/epoch - 92ms/step
# Epoch 279/2000
# 1/1 - 0s - loss: 0.9641 - mse: 0.9641 - val_loss: 5.5668 - val_mse: 5.5668 - 81ms/epoch - 81ms/step
# Epoch 280/2000
# 1/1 - 0s - loss: 1.2596 - mse: 1.2596 - val_loss: 2.3704 - val_mse: 2.3704 - 83ms/epoch - 83ms/step
# Epoch 281/2000
# 1/1 - 0s - loss: 0.6507 - mse: 0.6507 - val_loss: 2.6092 - val_mse: 2.6092 - 93ms/epoch - 93ms/step
# Epoch 282/2000
# 1/1 - 0s - loss: 0.5247 - mse: 0.5247 - val_loss: 2.6708 - val_mse: 2.6708 - 82ms/epoch - 82ms/step
# Epoch 283/2000
# 1/1 - 0s - loss: 0.4985 - mse: 0.4985 - val_loss: 2.1630 - val_mse: 2.1630 - 81ms/epoch - 81ms/step
# Epoch 284/2000
# 1/1 - 0s - loss: 0.5572 - mse: 0.5572 - val_loss: 3.1054 - val_mse: 3.1054 - 82ms/epoch - 82ms/step
# Epoch 285/2000
# 1/1 - 0s - loss: 0.7719 - mse: 0.7719 - val_loss: 4.9320 - val_mse: 4.9320 - 85ms/epoch - 85ms/step
# Epoch 286/2000
# 1/1 - 0s - loss: 1.1189 - mse: 1.1189 - val_loss: 2.4458 - val_mse: 2.4458 - 93ms/epoch - 93ms/step
# Epoch 287/2000
# 1/1 - 0s - loss: 0.8381 - mse: 0.8381 - val_loss: 2.7594 - val_mse: 2.7594 - 90ms/epoch - 90ms/step
# Epoch 288/2000
# 1/1 - 0s - loss: 0.5477 - mse: 0.5477 - val_loss: 2.4280 - val_mse: 2.4280 - 77ms/epoch - 77ms/step
# Epoch 289/2000
# 1/1 - 0s - loss: 0.4947 - mse: 0.4947 - val_loss: 2.8664 - val_mse: 2.8664 - 91ms/epoch - 91ms/step
# Epoch 290/2000
# 1/1 - 0s - loss: 0.5117 - mse: 0.5117 - val_loss: 2.2831 - val_mse: 2.2831 - 92ms/epoch - 92ms/step
# Epoch 291/2000
# 1/1 - 0s - loss: 0.7026 - mse: 0.7026 - val_loss: 3.0130 - val_mse: 3.0130 - 88ms/epoch - 88ms/step
# Epoch 292/2000
# 1/1 - 0s - loss: 0.9621 - mse: 0.9621 - val_loss: 4.2623 - val_mse: 4.2623 - 93ms/epoch - 93ms/step
# Epoch 293/2000
# 1/1 - 0s - loss: 1.2638 - mse: 1.2638 - val_loss: 2.8838 - val_mse: 2.8838 - 94ms/epoch - 94ms/step
# Epoch 294/2000
# 1/1 - 0s - loss: 0.5836 - mse: 0.5836 - val_loss: 2.5205 - val_mse: 2.5205 - 81ms/epoch - 81ms/step
# Epoch 295/2000
# 1/1 - 0s - loss: 0.4734 - mse: 0.4734 - val_loss: 2.2118 - val_mse: 2.2118 - 86ms/epoch - 86ms/step
# Epoch 296/2000
# 1/1 - 0s - loss: 0.4400 - mse: 0.4400 - val_loss: 2.3339 - val_mse: 2.3339 - 72ms/epoch - 72ms/step
# Epoch 297/2000
# 1/1 - 0s - loss: 0.4396 - mse: 0.4396 - val_loss: 2.1876 - val_mse: 2.1876 - 94ms/epoch - 94ms/step
# Epoch 298/2000
# 1/1 - 0s - loss: 0.5040 - mse: 0.5040 - val_loss: 2.6794 - val_mse: 2.6794 - 80ms/epoch - 80ms/step
# Epoch 299/2000
# 1/1 - 0s - loss: 0.8277 - mse: 0.8277 - val_loss: 5.4300 - val_mse: 5.4300 - 74ms/epoch - 74ms/step
# Epoch 300/2000
# 1/1 - 0s - loss: 1.3628 - mse: 1.3628 - val_loss: 2.9569 - val_mse: 2.9569 - 92ms/epoch - 92ms/step
# Epoch 301/2000
# 1/1 - 0s - loss: 1.0728 - mse: 1.0728 - val_loss: 2.6979 - val_mse: 2.6979 - 86ms/epoch - 86ms/step
# Epoch 302/2000
# 1/1 - 0s - loss: 0.5889 - mse: 0.5889 - val_loss: 2.2097 - val_mse: 2.2097 - 78ms/epoch - 78ms/step
# Epoch 303/2000
# 1/1 - 0s - loss: 0.4578 - mse: 0.4578 - val_loss: 2.1291 - val_mse: 2.1291 - 70ms/epoch - 70ms/step
# Epoch 304/2000
# 1/1 - 0s - loss: 0.4304 - mse: 0.4304 - val_loss: 2.0781 - val_mse: 2.0781 - 91ms/epoch - 91ms/step
# Epoch 305/2000
# 1/1 - 0s - loss: 0.4166 - mse: 0.4166 - val_loss: 2.0596 - val_mse: 2.0596 - 96ms/epoch - 96ms/step
# Epoch 306/2000
# 1/1 - 0s - loss: 0.4048 - mse: 0.4048 - val_loss: 2.0073 - val_mse: 2.0073 - 95ms/epoch - 95ms/step
# Epoch 307/2000
# 1/1 - 0s - loss: 0.3946 - mse: 0.3946 - val_loss: 2.0234 - val_mse: 2.0234 - 82ms/epoch - 82ms/step
# Epoch 308/2000
# 1/1 - 0s - loss: 0.3878 - mse: 0.3878 - val_loss: 1.9905 - val_mse: 1.9905 - 81ms/epoch - 81ms/step
# Epoch 309/2000
# 1/1 - 0s - loss: 0.4045 - mse: 0.4045 - val_loss: 2.2593 - val_mse: 2.2593 - 92ms/epoch - 92ms/step
# Epoch 310/2000
# 1/1 - 0s - loss: 0.6116 - mse: 0.6116 - val_loss: 5.6591 - val_mse: 5.6591 - 73ms/epoch - 73ms/step
# Epoch 311/2000
# 1/1 - 0s - loss: 1.5542 - mse: 1.5542 - val_loss: 3.4972 - val_mse: 3.4972 - 90ms/epoch - 90ms/step
# Epoch 312/2000
# 1/1 - 0s - loss: 1.4435 - mse: 1.4435 - val_loss: 3.6571 - val_mse: 3.6571 - 83ms/epoch - 83ms/step
# Epoch 313/2000
# 1/1 - 0s - loss: 0.8962 - mse: 0.8962 - val_loss: 2.4947 - val_mse: 2.4947 - 81ms/epoch - 81ms/step
# Epoch 314/2000
# 1/1 - 0s - loss: 0.7518 - mse: 0.7518 - val_loss: 3.9645 - val_mse: 3.9645 - 85ms/epoch - 85ms/step
# Epoch 315/2000
# 1/1 - 0s - loss: 0.7944 - mse: 0.7944 - val_loss: 1.9670 - val_mse: 1.9670 - 83ms/epoch - 83ms/step
# Epoch 316/2000
# 1/1 - 0s - loss: 0.4218 - mse: 0.4218 - val_loss: 1.8840 - val_mse: 1.8840 - 81ms/epoch - 81ms/step
# Epoch 317/2000
# 1/1 - 0s - loss: 0.4002 - mse: 0.4002 - val_loss: 1.8601 - val_mse: 1.8601 - 72ms/epoch - 72ms/step
# Epoch 318/2000
# 1/1 - 0s - loss: 0.3987 - mse: 0.3987 - val_loss: 1.9417 - val_mse: 1.9417 - 88ms/epoch - 88ms/step
# Epoch 319/2000
# 1/1 - 0s - loss: 0.4246 - mse: 0.4246 - val_loss: 1.9571 - val_mse: 1.9571 - 74ms/epoch - 74ms/step
# Epoch 320/2000
# 1/1 - 0s - loss: 0.5239 - mse: 0.5239 - val_loss: 3.2056 - val_mse: 3.2056 - 80ms/epoch - 80ms/step
# Epoch 321/2000
# 1/1 - 0s - loss: 0.7530 - mse: 0.7530 - val_loss: 2.1544 - val_mse: 2.1544 - 92ms/epoch - 92ms/step
# Epoch 322/2000
# 1/1 - 0s - loss: 0.8758 - mse: 0.8758 - val_loss: 2.7056 - val_mse: 2.7056 - 88ms/epoch - 88ms/step
# Epoch 323/2000
# 1/1 - 0s - loss: 0.5971 - mse: 0.5971 - val_loss: 1.8877 - val_mse: 1.8877 - 92ms/epoch - 92ms/step
# Epoch 324/2000
# 1/1 - 0s - loss: 0.4364 - mse: 0.4364 - val_loss: 1.9572 - val_mse: 1.9572 - 85ms/epoch - 85ms/step
# Epoch 325/2000
# 1/1 - 0s - loss: 0.4492 - mse: 0.4492 - val_loss: 2.2187 - val_mse: 2.2187 - 74ms/epoch - 74ms/step
# Epoch 326/2000
# 1/1 - 0s - loss: 0.5340 - mse: 0.5340 - val_loss: 3.8725 - val_mse: 3.8725 - 86ms/epoch - 86ms/step
# Epoch 327/2000
# 1/1 - 0s - loss: 0.7455 - mse: 0.7455 - val_loss: 1.9428 - val_mse: 1.9428 - 80ms/epoch - 80ms/step
# Epoch 328/2000
# 1/1 - 0s - loss: 0.4759 - mse: 0.4759 - val_loss: 2.9750 - val_mse: 2.9750 - 90ms/epoch - 90ms/step
# Epoch 329/2000
# 1/1 - 0s - loss: 0.6061 - mse: 0.6061 - val_loss: 1.9685 - val_mse: 1.9685 - 97ms/epoch - 97ms/step
# Epoch 330/2000
# 1/1 - 0s - loss: 0.5212 - mse: 0.5212 - val_loss: 2.6959 - val_mse: 2.6959 - 80ms/epoch - 80ms/step
# Epoch 331/2000
# 1/1 - 0s - loss: 0.5656 - mse: 0.5656 - val_loss: 1.7952 - val_mse: 1.7952 - 83ms/epoch - 83ms/step
# Epoch 332/2000
# 1/1 - 0s - loss: 0.6245 - mse: 0.6245 - val_loss: 1.4950 - val_mse: 1.4950 - 89ms/epoch - 89ms/step
# Epoch 333/2000
# 1/1 - 0s - loss: 0.5447 - mse: 0.5447 - val_loss: 3.5728 - val_mse: 3.5728 - 90ms/epoch - 90ms/step
# Epoch 334/2000
# 1/1 - 0s - loss: 1.4055 - mse: 1.4055 - val_loss: 4.4164 - val_mse: 4.4164 - 85ms/epoch - 85ms/step
# Epoch 335/2000
# 1/1 - 0s - loss: 1.2812 - mse: 1.2812 - val_loss: 2.5129 - val_mse: 2.5129 - 83ms/epoch - 83ms/step
# Epoch 336/2000
# 1/1 - 0s - loss: 0.4793 - mse: 0.4793 - val_loss: 1.8128 - val_mse: 1.8128 - 73ms/epoch - 73ms/step
# Epoch 337/2000
# 1/1 - 0s - loss: 0.3795 - mse: 0.3795 - val_loss: 1.7384 - val_mse: 1.7384 - 88ms/epoch - 88ms/step
# Epoch 338/2000
# 1/1 - 0s - loss: 0.3479 - mse: 0.3479 - val_loss: 1.6765 - val_mse: 1.6765 - 82ms/epoch - 82ms/step
# Epoch 339/2000
# 1/1 - 0s - loss: 0.3393 - mse: 0.3393 - val_loss: 1.7664 - val_mse: 1.7664 - 89ms/epoch - 89ms/step
# Epoch 340/2000
# 1/1 - 0s - loss: 0.3382 - mse: 0.3382 - val_loss: 1.6646 - val_mse: 1.6646 - 90ms/epoch - 90ms/step
# Epoch 341/2000
# 1/1 - 0s - loss: 0.3612 - mse: 0.3612 - val_loss: 2.0741 - val_mse: 2.0741 - 91ms/epoch - 91ms/step
# Epoch 342/2000
# 1/1 - 0s - loss: 0.4379 - mse: 0.4379 - val_loss: 1.8092 - val_mse: 1.8092 - 85ms/epoch - 85ms/step
# Epoch 343/2000
# 1/1 - 0s - loss: 0.7071 - mse: 0.7071 - val_loss: 2.7852 - val_mse: 2.7852 - 92ms/epoch - 92ms/step
# Epoch 344/2000
# 1/1 - 0s - loss: 0.6929 - mse: 0.6929 - val_loss: 2.0406 - val_mse: 2.0406 - 82ms/epoch - 82ms/step
# Epoch 345/2000
# 1/1 - 0s - loss: 0.5973 - mse: 0.5973 - val_loss: 1.9399 - val_mse: 1.9399 - 87ms/epoch - 87ms/step
# Epoch 346/2000
# 1/1 - 0s - loss: 0.3778 - mse: 0.3778 - val_loss: 1.6783 - val_mse: 1.6783 - 85ms/epoch - 85ms/step
# Epoch 347/2000
# 1/1 - 0s - loss: 0.3204 - mse: 0.3204 - val_loss: 1.6033 - val_mse: 1.6033 - 81ms/epoch - 81ms/step
# Epoch 348/2000
# 1/1 - 0s - loss: 0.3061 - mse: 0.3061 - val_loss: 1.6727 - val_mse: 1.6727 - 80ms/epoch - 80ms/step
# Epoch 349/2000
# 1/1 - 0s - loss: 0.2983 - mse: 0.2983 - val_loss: 1.5898 - val_mse: 1.5898 - 81ms/epoch - 81ms/step
# Epoch 350/2000
# 1/1 - 0s - loss: 0.3006 - mse: 0.3006 - val_loss: 2.1211 - val_mse: 2.1211 - 83ms/epoch - 83ms/step
# Epoch 351/2000
# 1/1 - 0s - loss: 0.3491 - mse: 0.3491 - val_loss: 1.6827 - val_mse: 1.6827 - 88ms/epoch - 88ms/step
# Epoch 352/2000
# 1/1 - 0s - loss: 0.5421 - mse: 0.5421 - val_loss: 4.9037 - val_mse: 4.9037 - 86ms/epoch - 86ms/step
# Epoch 353/2000
# 1/1 - 0s - loss: 1.1972 - mse: 1.1972 - val_loss: 1.9364 - val_mse: 1.9364 - 90ms/epoch - 90ms/step
# Epoch 354/2000
# 1/1 - 0s - loss: 0.7645 - mse: 0.7645 - val_loss: 1.8254 - val_mse: 1.8254 - 95ms/epoch - 95ms/step
# Epoch 355/2000
# 1/1 - 0s - loss: 0.4984 - mse: 0.4984 - val_loss: 2.4119 - val_mse: 2.4119 - 92ms/epoch - 92ms/step
# Epoch 356/2000
# 1/1 - 0s - loss: 0.5911 - mse: 0.5911 - val_loss: 1.8478 - val_mse: 1.8478 - 80ms/epoch - 80ms/step
# Epoch 357/2000
# 1/1 - 0s - loss: 0.4431 - mse: 0.4431 - val_loss: 2.5402 - val_mse: 2.5402 - 91ms/epoch - 91ms/step
# Epoch 358/2000
# 1/1 - 0s - loss: 0.3945 - mse: 0.3945 - val_loss: 1.4570 - val_mse: 1.4570 - 87ms/epoch - 87ms/step
# Epoch 359/2000
# 1/1 - 0s - loss: 0.3140 - mse: 0.3140 - val_loss: 2.1258 - val_mse: 2.1258 - 82ms/epoch - 82ms/step
# Epoch 360/2000
# 1/1 - 0s - loss: 0.3651 - mse: 0.3651 - val_loss: 1.6081 - val_mse: 1.6081 - 93ms/epoch - 93ms/step
# Epoch 361/2000
# 1/1 - 0s - loss: 0.4941 - mse: 0.4941 - val_loss: 2.7492 - val_mse: 2.7492 - 92ms/epoch - 92ms/step
# Epoch 362/2000
# 1/1 - 0s - loss: 0.6540 - mse: 0.6540 - val_loss: 1.8761 - val_mse: 1.8761 - 87ms/epoch - 87ms/step
# Epoch 363/2000
# 1/1 - 0s - loss: 0.7558 - mse: 0.7558 - val_loss: 1.6075 - val_mse: 1.6075 - 92ms/epoch - 92ms/step
# Epoch 364/2000
# 1/1 - 0s - loss: 0.3863 - mse: 0.3863 - val_loss: 1.8158 - val_mse: 1.8158 - 78ms/epoch - 78ms/step
# Epoch 365/2000
# 1/1 - 0s - loss: 0.4055 - mse: 0.4055 - val_loss: 1.7772 - val_mse: 1.7772 - 89ms/epoch - 89ms/step
# Epoch 366/2000
# 1/1 - 0s - loss: 0.4742 - mse: 0.4742 - val_loss: 3.3455 - val_mse: 3.3455 - 93ms/epoch - 93ms/step
# Epoch 367/2000
# 1/1 - 0s - loss: 0.6325 - mse: 0.6325 - val_loss: 1.4816 - val_mse: 1.4816 - 92ms/epoch - 92ms/step
# Epoch 368/2000
# 1/1 - 0s - loss: 0.3480 - mse: 0.3480 - val_loss: 2.5098 - val_mse: 2.5098 - 82ms/epoch - 82ms/step
# Epoch 369/2000
# 1/1 - 0s - loss: 0.4132 - mse: 0.4132 - val_loss: 1.5548 - val_mse: 1.5548 - 97ms/epoch - 97ms/step
# Epoch 370/2000
# 1/1 - 0s - loss: 0.4394 - mse: 0.4394 - val_loss: 2.5049 - val_mse: 2.5049 - 92ms/epoch - 92ms/step
# Epoch 371/2000
# 1/1 - 0s - loss: 0.4929 - mse: 0.4929 - val_loss: 1.6064 - val_mse: 1.6064 - 81ms/epoch - 81ms/step
# Epoch 372/2000
# 1/1 - 0s - loss: 0.5577 - mse: 0.5577 - val_loss: 1.4430 - val_mse: 1.4430 - 94ms/epoch - 94ms/step
# Epoch 373/2000
# 1/1 - 0s - loss: 0.3300 - mse: 0.3300 - val_loss: 1.3829 - val_mse: 1.3829 - 94ms/epoch - 94ms/step
# Epoch 374/2000
# 1/1 - 0s - loss: 0.3011 - mse: 0.3011 - val_loss: 1.7989 - val_mse: 1.7989 - 81ms/epoch - 81ms/step
# Epoch 375/2000
# 1/1 - 0s - loss: 0.3260 - mse: 0.3260 - val_loss: 1.5116 - val_mse: 1.5116 - 87ms/epoch - 87ms/step
# Epoch 376/2000
# 1/1 - 0s - loss: 0.3860 - mse: 0.3860 - val_loss: 3.4055 - val_mse: 3.4055 - 78ms/epoch - 78ms/step
# Epoch 377/2000
# 1/1 - 0s - loss: 0.6033 - mse: 0.6033 - val_loss: 1.4560 - val_mse: 1.4560 - 95ms/epoch - 95ms/step
# Epoch 378/2000
# 1/1 - 0s - loss: 0.4529 - mse: 0.4529 - val_loss: 3.8053 - val_mse: 3.8053 - 86ms/epoch - 86ms/step
# Epoch 379/2000
# 1/1 - 0s - loss: 0.6672 - mse: 0.6672 - val_loss: 1.4718 - val_mse: 1.4718 - 92ms/epoch - 92ms/step
# Epoch 380/2000
# 1/1 - 0s - loss: 0.4825 - mse: 0.4825 - val_loss: 1.4578 - val_mse: 1.4578 - 81ms/epoch - 81ms/step
# Epoch 381/2000
# 1/1 - 0s - loss: 0.4382 - mse: 0.4382 - val_loss: 1.4156 - val_mse: 1.4156 - 92ms/epoch - 92ms/step
# Epoch 382/2000
# 1/1 - 0s - loss: 0.4260 - mse: 0.4260 - val_loss: 1.9080 - val_mse: 1.9080 - 94ms/epoch - 94ms/step
# Epoch 383/2000
# 1/1 - 0s - loss: 0.3643 - mse: 0.3643 - val_loss: 1.3907 - val_mse: 1.3907 - 92ms/epoch - 92ms/step
# Epoch 384/2000
# 1/1 - 0s - loss: 0.3382 - mse: 0.3382 - val_loss: 2.6556 - val_mse: 2.6556 - 80ms/epoch - 80ms/step
# Epoch 385/2000
# 1/1 - 0s - loss: 0.3895 - mse: 0.3895 - val_loss: 1.2987 - val_mse: 1.2987 - 91ms/epoch - 91ms/step
# Epoch 386/2000
# 1/1 - 0s - loss: 0.3011 - mse: 0.3011 - val_loss: 2.6099 - val_mse: 2.6099 - 72ms/epoch - 72ms/step
# Epoch 387/2000
# 1/1 - 0s - loss: 0.3341 - mse: 0.3341 - val_loss: 1.2474 - val_mse: 1.2474 - 92ms/epoch - 92ms/step
# Epoch 388/2000
# 1/1 - 0s - loss: 0.3576 - mse: 0.3576 - val_loss: 2.8554 - val_mse: 2.8554 - 94ms/epoch - 94ms/step
# Epoch 389/2000
# 1/1 - 0s - loss: 0.7105 - mse: 0.7105 - val_loss: 2.4028 - val_mse: 2.4028 - 91ms/epoch - 91ms/step
# Epoch 390/2000
# 1/1 - 0s - loss: 1.0534 - mse: 1.0534 - val_loss: 2.2204 - val_mse: 2.2204 - 81ms/epoch - 81ms/step
# Epoch 391/2000
# 1/1 - 0s - loss: 0.6276 - mse: 0.6276 - val_loss: 2.1887 - val_mse: 2.1887 - 92ms/epoch - 92ms/step
# Epoch 392/2000
# 1/1 - 0s - loss: 0.3366 - mse: 0.3366 - val_loss: 1.3277 - val_mse: 1.3277 - 82ms/epoch - 82ms/step
# Epoch 393/2000
# 1/1 - 0s - loss: 0.2688 - mse: 0.2688 - val_loss: 2.0968 - val_mse: 2.0968 - 96ms/epoch - 96ms/step
# Epoch 394/2000
# 1/1 - 0s - loss: 0.2528 - mse: 0.2528 - val_loss: 1.2291 - val_mse: 1.2291 - 89ms/epoch - 89ms/step
# Epoch 395/2000
# 1/1 - 0s - loss: 0.2572 - mse: 0.2572 - val_loss: 2.4685 - val_mse: 2.4685 - 86ms/epoch - 86ms/step
# Epoch 396/2000
# 1/1 - 0s - loss: 0.3738 - mse: 0.3738 - val_loss: 1.3429 - val_mse: 1.3429 - 92ms/epoch - 92ms/step
# Epoch 397/2000
# 1/1 - 0s - loss: 0.5406 - mse: 0.5406 - val_loss: 2.0814 - val_mse: 2.0814 - 85ms/epoch - 85ms/step
# Epoch 398/2000
# 1/1 - 0s - loss: 0.4297 - mse: 0.4297 - val_loss: 1.3165 - val_mse: 1.3165 - 84ms/epoch - 84ms/step
# Epoch 399/2000
# 1/1 - 0s - loss: 0.3260 - mse: 0.3260 - val_loss: 1.8270 - val_mse: 1.8270 - 93ms/epoch - 93ms/step
# Epoch 400/2000
# 1/1 - 0s - loss: 0.2634 - mse: 0.2634 - val_loss: 1.1458 - val_mse: 1.1458 - 90ms/epoch - 90ms/step
# Epoch 401/2000
# 1/1 - 0s - loss: 0.2525 - mse: 0.2525 - val_loss: 2.5335 - val_mse: 2.5335 - 87ms/epoch - 87ms/step
# Epoch 402/2000
# 1/1 - 0s - loss: 0.3527 - mse: 0.3527 - val_loss: 1.2086 - val_mse: 1.2086 - 81ms/epoch - 81ms/step
# Epoch 403/2000
# 1/1 - 0s - loss: 0.3485 - mse: 0.3485 - val_loss: 3.4578 - val_mse: 3.4578 - 91ms/epoch - 91ms/step
# Epoch 404/2000
# 1/1 - 0s - loss: 0.5130 - mse: 0.5130 - val_loss: 1.0814 - val_mse: 1.0814 - 81ms/epoch - 81ms/step
# Epoch 405/2000
# 1/1 - 0s - loss: 0.4094 - mse: 0.4094 - val_loss: 2.9024 - val_mse: 2.9024 - 75ms/epoch - 75ms/step
# Epoch 406/2000
# 1/1 - 0s - loss: 0.4927 - mse: 0.4927 - val_loss: 2.0118 - val_mse: 2.0118 - 74ms/epoch - 74ms/step
# Epoch 407/2000
# 1/1 - 0s - loss: 0.5005 - mse: 0.5005 - val_loss: 2.4771 - val_mse: 2.4771 - 90ms/epoch - 90ms/step
# Epoch 408/2000
# 1/1 - 0s - loss: 0.6397 - mse: 0.6397 - val_loss: 1.4856 - val_mse: 1.4856 - 83ms/epoch - 83ms/step
# Epoch 409/2000
# 1/1 - 0s - loss: 0.5612 - mse: 0.5612 - val_loss: 1.1383 - val_mse: 1.1383 - 84ms/epoch - 84ms/step
# Epoch 410/2000
# 1/1 - 0s - loss: 0.3855 - mse: 0.3855 - val_loss: 1.4270 - val_mse: 1.4270 - 90ms/epoch - 90ms/step
# Epoch 411/2000
# 1/1 - 0s - loss: 0.2672 - mse: 0.2672 - val_loss: 1.2957 - val_mse: 1.2957 - 82ms/epoch - 82ms/step
# Epoch 412/2000
# 1/1 - 0s - loss: 0.2865 - mse: 0.2865 - val_loss: 2.3706 - val_mse: 2.3706 - 82ms/epoch - 82ms/step
# Epoch 413/2000
# 1/1 - 0s - loss: 0.3029 - mse: 0.3029 - val_loss: 1.1071 - val_mse: 1.1071 - 89ms/epoch - 89ms/step
# Epoch 414/2000
# 1/1 - 0s - loss: 0.2379 - mse: 0.2379 - val_loss: 2.4610 - val_mse: 2.4610 - 91ms/epoch - 91ms/step
# Epoch 415/2000
# 1/1 - 0s - loss: 0.3040 - mse: 0.3040 - val_loss: 1.1535 - val_mse: 1.1535 - 96ms/epoch - 96ms/step
# Epoch 416/2000
# ...
# 1/1 - 0s - loss: 0.0739 - mse: 0.0739 - val_loss: 1.3905 - val_mse: 1.3905 - 75ms/epoch - 75ms/step
# Epoch 1864/2000
# 1/1 - 0s - loss: 0.0965 - mse: 0.0965 - val_loss: 1.7086 - val_mse: 1.7086 - 79ms/epoch - 79ms/step
# Epoch 1865/2000
# 1/1 - 0s - loss: 0.1135 - mse: 0.1135 - val_loss: 1.2470 - val_mse: 1.2470 - 75ms/epoch - 75ms/step
# Epoch 1866/2000
# 1/1 - 0s - loss: 0.0840 - mse: 0.0840 - val_loss: 1.5727 - val_mse: 1.5727 - 87ms/epoch - 87ms/step
# Epoch 1867/2000
# 1/1 - 0s - loss: 0.0582 - mse: 0.0582 - val_loss: 1.2774 - val_mse: 1.2774 - 73ms/epoch - 73ms/step
# Epoch 1868/2000
# 1/1 - 0s - loss: 0.0543 - mse: 0.0543 - val_loss: 1.4750 - val_mse: 1.4750 - 80ms/epoch - 80ms/step
# Epoch 1869/2000
# 1/1 - 0s - loss: 0.0362 - mse: 0.0362 - val_loss: 1.2683 - val_mse: 1.2683 - 91ms/epoch - 91ms/step
# Epoch 1870/2000
# 1/1 - 0s - loss: 0.0370 - mse: 0.0370 - val_loss: 1.4365 - val_mse: 1.4365 - 79ms/epoch - 79ms/step
# Epoch 1871/2000
# 1/1 - 0s - loss: 0.0323 - mse: 0.0323 - val_loss: 1.2396 - val_mse: 1.2396 - 96ms/epoch - 96ms/step
# Epoch 1872/2000
# 1/1 - 0s - loss: 0.0392 - mse: 0.0392 - val_loss: 1.4034 - val_mse: 1.4034 - 72ms/epoch - 72ms/step
# Epoch 1873/2000
# 1/1 - 0s - loss: 0.0401 - mse: 0.0401 - val_loss: 1.2215 - val_mse: 1.2215 - 89ms/epoch - 89ms/step
# Epoch 1874/2000
# 1/1 - 0s - loss: 0.0526 - mse: 0.0526 - val_loss: 1.3087 - val_mse: 1.3087 - 75ms/epoch - 75ms/step
# Epoch 1875/2000
# 1/1 - 0s - loss: 0.0505 - mse: 0.0505 - val_loss: 1.3031 - val_mse: 1.3031 - 69ms/epoch - 69ms/step
# Epoch 1876/2000
# 1/1 - 0s - loss: 0.0568 - mse: 0.0568 - val_loss: 1.1543 - val_mse: 1.1543 - 88ms/epoch - 88ms/step
# Epoch 1877/2000
# 1/1 - 0s - loss: 0.0741 - mse: 0.0741 - val_loss: 1.6635 - val_mse: 1.6635 - 76ms/epoch - 76ms/step
# Epoch 1878/2000
# 1/1 - 0s - loss: 0.0668 - mse: 0.0668 - val_loss: 0.9217 - val_mse: 0.9217 - 72ms/epoch - 72ms/step
# Epoch 1879/2000
# 1/1 - 0s - loss: 0.1253 - mse: 0.1253 - val_loss: 2.3353 - val_mse: 2.3353 - 79ms/epoch - 79ms/step
# Epoch 1880/2000
# 1/1 - 0s - loss: 0.1716 - mse: 0.1716 - val_loss: 0.8194 - val_mse: 0.8194 - 79ms/epoch - 79ms/step
# Epoch 1881/2000
# 1/1 - 0s - loss: 0.0965 - mse: 0.0965 - val_loss: 1.9281 - val_mse: 1.9281 - 90ms/epoch - 90ms/step
# Epoch 1882/2000
# 1/1 - 0s - loss: 0.0642 - mse: 0.0642 - val_loss: 1.2906 - val_mse: 1.2906 - 77ms/epoch - 77ms/step
# Epoch 1883/2000
# 1/1 - 0s - loss: 0.0693 - mse: 0.0693 - val_loss: 1.8345 - val_mse: 1.8345 - 82ms/epoch - 82ms/step
# Epoch 1884/2000
# 1/1 - 0s - loss: 0.0871 - mse: 0.0871 - val_loss: 1.3299 - val_mse: 1.3299 - 74ms/epoch - 74ms/step
# Epoch 1885/2000
# 1/1 - 0s - loss: 0.0977 - mse: 0.0977 - val_loss: 1.7487 - val_mse: 1.7487 - 93ms/epoch - 93ms/step
# Epoch 1886/2000
# 1/1 - 0s - loss: 0.1031 - mse: 0.1031 - val_loss: 1.2338 - val_mse: 1.2338 - 92ms/epoch - 92ms/step
# Epoch 1887/2000
# 1/1 - 0s - loss: 0.0859 - mse: 0.0859 - val_loss: 1.5771 - val_mse: 1.5771 - 95ms/epoch - 95ms/step
# Epoch 1888/2000
# 1/1 - 0s - loss: 0.0591 - mse: 0.0591 - val_loss: 1.2446 - val_mse: 1.2446 - 90ms/epoch - 90ms/step
# Epoch 1889/2000
# 1/1 - 0s - loss: 0.0517 - mse: 0.0517 - val_loss: 1.4655 - val_mse: 1.4655 - 78ms/epoch - 78ms/step
# Epoch 1890/2000
# 1/1 - 0s - loss: 0.0363 - mse: 0.0363 - val_loss: 1.2542 - val_mse: 1.2542 - 90ms/epoch - 90ms/step
# Epoch 1891/2000
# 1/1 - 0s - loss: 0.0353 - mse: 0.0353 - val_loss: 1.4202 - val_mse: 1.4202 - 84ms/epoch - 84ms/step
# Epoch 1892/2000
# 1/1 - 0s - loss: 0.0299 - mse: 0.0299 - val_loss: 1.2475 - val_mse: 1.2475 - 85ms/epoch - 85ms/step
# Epoch 1893/2000
# 1/1 - 0s - loss: 0.0328 - mse: 0.0328 - val_loss: 1.4021 - val_mse: 1.4021 - 92ms/epoch - 92ms/step
# Epoch 1894/2000
# 1/1 - 0s - loss: 0.0324 - mse: 0.0324 - val_loss: 1.2286 - val_mse: 1.2286 - 87ms/epoch - 87ms/step
# Epoch 1895/2000
# 1/1 - 0s - loss: 0.0397 - mse: 0.0397 - val_loss: 1.3865 - val_mse: 1.3865 - 67ms/epoch - 67ms/step
# Epoch 1896/2000
# 1/1 - 0s - loss: 0.0411 - mse: 0.0411 - val_loss: 1.2000 - val_mse: 1.2000 - 96ms/epoch - 96ms/step
# Epoch 1897/2000
# 1/1 - 0s - loss: 0.0508 - mse: 0.0508 - val_loss: 1.3538 - val_mse: 1.3538 - 76ms/epoch - 76ms/step
# Epoch 1898/2000
# 1/1 - 0s - loss: 0.0454 - mse: 0.0454 - val_loss: 1.1803 - val_mse: 1.1803 - 73ms/epoch - 73ms/step
# Epoch 1899/2000
# 1/1 - 0s - loss: 0.0504 - mse: 0.0504 - val_loss: 1.2981 - val_mse: 1.2981 - 75ms/epoch - 75ms/step
# Epoch 1900/2000
# 1/1 - 0s - loss: 0.0406 - mse: 0.0406 - val_loss: 1.2127 - val_mse: 1.2127 - 81ms/epoch - 81ms/step
# Epoch 1901/2000
# 1/1 - 0s - loss: 0.0435 - mse: 0.0435 - val_loss: 1.1610 - val_mse: 1.1610 - 92ms/epoch - 92ms/step
# Epoch 1902/2000
# 1/1 - 0s - loss: 0.0560 - mse: 0.0560 - val_loss: 1.7007 - val_mse: 1.7007 - 71ms/epoch - 71ms/step
# Epoch 1903/2000
# 1/1 - 0s - loss: 0.0980 - mse: 0.0980 - val_loss: 1.0915 - val_mse: 1.0915 - 89ms/epoch - 89ms/step
# Epoch 1904/2000
# 1/1 - 0s - loss: 0.2294 - mse: 0.2294 - val_loss: 2.5218 - val_mse: 2.5218 - 99ms/epoch - 99ms/step
# Epoch 1905/2000
# 1/1 - 0s - loss: 0.2100 - mse: 0.2100 - val_loss: 0.9700 - val_mse: 0.9700 - 75ms/epoch - 75ms/step
# Epoch 1906/2000
# 1/1 - 0s - loss: 0.1188 - mse: 0.1188 - val_loss: 1.7011 - val_mse: 1.7011 - 89ms/epoch - 89ms/step
# Epoch 1907/2000
# 1/1 - 0s - loss: 0.0361 - mse: 0.0361 - val_loss: 1.3089 - val_mse: 1.3089 - 79ms/epoch - 79ms/step
# Epoch 1908/2000
# 1/1 - 0s - loss: 0.0429 - mse: 0.0429 - val_loss: 1.6050 - val_mse: 1.6050 - 85ms/epoch - 85ms/step
# Epoch 1909/2000
# 1/1 - 0s - loss: 0.0634 - mse: 0.0634 - val_loss: 1.3260 - val_mse: 1.3260 - 86ms/epoch - 86ms/step
# Epoch 1910/2000
# 1/1 - 0s - loss: 0.0715 - mse: 0.0715 - val_loss: 1.6101 - val_mse: 1.6101 - 95ms/epoch - 95ms/step
# Epoch 1911/2000
# 1/1 - 0s - loss: 0.0848 - mse: 0.0848 - val_loss: 1.2747 - val_mse: 1.2747 - 81ms/epoch - 81ms/step
# Epoch 1912/2000
# 1/1 - 0s - loss: 0.0710 - mse: 0.0710 - val_loss: 1.5780 - val_mse: 1.5780 - 78ms/epoch - 78ms/step
# Epoch 1913/2000
# 1/1 - 0s - loss: 0.0562 - mse: 0.0562 - val_loss: 1.2430 - val_mse: 1.2430 - 93ms/epoch - 93ms/step
# Epoch 1914/2000
# 1/1 - 0s - loss: 0.0489 - mse: 0.0489 - val_loss: 1.5670 - val_mse: 1.5670 - 90ms/epoch - 90ms/step
# Epoch 1915/2000
# 1/1 - 0s - loss: 0.0408 - mse: 0.0408 - val_loss: 1.2074 - val_mse: 1.2074 - 92ms/epoch - 92ms/step
# Epoch 1916/2000
# 1/1 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 1.6817 - val_mse: 1.6817 - 85ms/epoch - 85ms/step
# Epoch 1917/2000
# 1/1 - 0s - loss: 0.0428 - mse: 0.0428 - val_loss: 1.1532 - val_mse: 1.1532 - 84ms/epoch - 84ms/step
# Epoch 1918/2000
# 1/1 - 0s - loss: 0.0539 - mse: 0.0539 - val_loss: 2.0059 - val_mse: 2.0059 - 82ms/epoch - 82ms/step
# Epoch 1919/2000
# 1/1 - 0s - loss: 0.0707 - mse: 0.0707 - val_loss: 1.1271 - val_mse: 1.1271 - 81ms/epoch - 81ms/step
# Epoch 1920/2000
# 1/1 - 0s - loss: 0.0850 - mse: 0.0850 - val_loss: 2.2179 - val_mse: 2.2179 - 85ms/epoch - 85ms/step
# Epoch 1921/2000
# 1/1 - 0s - loss: 0.0823 - mse: 0.0823 - val_loss: 1.1047 - val_mse: 1.1047 - 88ms/epoch - 88ms/step
# Epoch 1922/2000
# 1/1 - 0s - loss: 0.0678 - mse: 0.0678 - val_loss: 2.0179 - val_mse: 2.0179 - 87ms/epoch - 87ms/step
# Epoch 1923/2000
# 1/1 - 0s - loss: 0.0515 - mse: 0.0515 - val_loss: 1.0983 - val_mse: 1.0983 - 72ms/epoch - 72ms/step
# Epoch 1924/2000
# 1/1 - 0s - loss: 0.0528 - mse: 0.0528 - val_loss: 1.7962 - val_mse: 1.7962 - 71ms/epoch - 71ms/step
# Epoch 1925/2000
# 1/1 - 0s - loss: 0.0648 - mse: 0.0648 - val_loss: 1.1462 - val_mse: 1.1462 - 83ms/epoch - 83ms/step
# Epoch 1926/2000
# 1/1 - 0s - loss: 0.1220 - mse: 0.1220 - val_loss: 1.4054 - val_mse: 1.4054 - 74ms/epoch - 74ms/step
# Epoch 1927/2000
# 1/1 - 0s - loss: 0.0993 - mse: 0.0993 - val_loss: 1.1330 - val_mse: 1.1330 - 89ms/epoch - 89ms/step
# Epoch 1928/2000
# 1/1 - 0s - loss: 0.1098 - mse: 0.1098 - val_loss: 1.6214 - val_mse: 1.6214 - 89ms/epoch - 89ms/step
# Epoch 1929/2000
# 1/1 - 0s - loss: 0.1266 - mse: 0.1266 - val_loss: 1.4644 - val_mse: 1.4644 - 75ms/epoch - 75ms/step
# Epoch 1930/2000
# 1/1 - 0s - loss: 0.0760 - mse: 0.0760 - val_loss: 1.2903 - val_mse: 1.2903 - 84ms/epoch - 84ms/step
# Epoch 1931/2000
# 1/1 - 0s - loss: 0.0694 - mse: 0.0694 - val_loss: 1.5485 - val_mse: 1.5485 - 78ms/epoch - 78ms/step
# Epoch 1932/2000
# 1/1 - 0s - loss: 0.0637 - mse: 0.0637 - val_loss: 1.1038 - val_mse: 1.1038 - 101ms/epoch - 101ms/step
# Epoch 1933/2000
# 1/1 - 0s - loss: 0.0648 - mse: 0.0648 - val_loss: 1.9110 - val_mse: 1.9110 - 85ms/epoch - 85ms/step
# Epoch 1934/2000
# 1/1 - 0s - loss: 0.0775 - mse: 0.0775 - val_loss: 1.0394 - val_mse: 1.0394 - 73ms/epoch - 73ms/step
# Epoch 1935/2000
# 1/1 - 0s - loss: 0.0820 - mse: 0.0820 - val_loss: 2.0167 - val_mse: 2.0167 - 80ms/epoch - 80ms/step
# Epoch 1936/2000
# 1/1 - 0s - loss: 0.0737 - mse: 0.0737 - val_loss: 1.0802 - val_mse: 1.0802 - 81ms/epoch - 81ms/step
# Epoch 1937/2000
# 1/1 - 0s - loss: 0.0512 - mse: 0.0512 - val_loss: 1.8082 - val_mse: 1.8082 - 71ms/epoch - 71ms/step
# Epoch 1938/2000
# 1/1 - 0s - loss: 0.0396 - mse: 0.0396 - val_loss: 1.1706 - val_mse: 1.1706 - 73ms/epoch - 73ms/step
# Epoch 1939/2000
# 1/1 - 0s - loss: 0.0301 - mse: 0.0301 - val_loss: 1.6637 - val_mse: 1.6637 - 98ms/epoch - 98ms/step
# Epoch 1940/2000
# 1/1 - 0s - loss: 0.0274 - mse: 0.0274 - val_loss: 1.2186 - val_mse: 1.2186 - 90ms/epoch - 90ms/step
# Epoch 1941/2000
# 1/1 - 0s - loss: 0.0293 - mse: 0.0293 - val_loss: 1.6234 - val_mse: 1.6234 - 83ms/epoch - 83ms/step
# Epoch 1942/2000
# 1/1 - 0s - loss: 0.0356 - mse: 0.0356 - val_loss: 1.2631 - val_mse: 1.2631 - 82ms/epoch - 82ms/step
# Epoch 1943/2000
# 1/1 - 0s - loss: 0.0570 - mse: 0.0570 - val_loss: 1.5478 - val_mse: 1.5478 - 84ms/epoch - 84ms/step
# Epoch 1944/2000
# 1/1 - 0s - loss: 0.0805 - mse: 0.0805 - val_loss: 1.2729 - val_mse: 1.2729 - 107ms/epoch - 107ms/step
# Epoch 1945/2000
# 1/1 - 0s - loss: 0.1106 - mse: 0.1106 - val_loss: 1.2850 - val_mse: 1.2850 - 79ms/epoch - 79ms/step
# Epoch 1946/2000
# 1/1 - 0s - loss: 0.0822 - mse: 0.0822 - val_loss: 1.2799 - val_mse: 1.2799 - 86ms/epoch - 86ms/step
# Epoch 1947/2000
# 1/1 - 0s - loss: 0.0623 - mse: 0.0623 - val_loss: 1.1745 - val_mse: 1.1745 - 83ms/epoch - 83ms/step
# Epoch 1948/2000
# 1/1 - 0s - loss: 0.0529 - mse: 0.0529 - val_loss: 1.5211 - val_mse: 1.5211 - 102ms/epoch - 102ms/step
# Epoch 1949/2000
# 1/1 - 0s - loss: 0.0487 - mse: 0.0487 - val_loss: 1.1291 - val_mse: 1.1291 - 75ms/epoch - 75ms/step
# Epoch 1950/2000
# 1/1 - 0s - loss: 0.0841 - mse: 0.0841 - val_loss: 1.8988 - val_mse: 1.8988 - 95ms/epoch - 95ms/step
# Epoch 1951/2000
# 1/1 - 0s - loss: 0.0669 - mse: 0.0669 - val_loss: 0.9870 - val_mse: 0.9870 - 83ms/epoch - 83ms/step
# Epoch 1952/2000
# 1/1 - 0s - loss: 0.1017 - mse: 0.1017 - val_loss: 2.2926 - val_mse: 2.2926 - 90ms/epoch - 90ms/step
# Epoch 1953/2000
# 1/1 - 0s - loss: 0.1297 - mse: 0.1297 - val_loss: 0.9291 - val_mse: 0.9291 - 95ms/epoch - 95ms/step
# Epoch 1954/2000
# 1/1 - 0s - loss: 0.0937 - mse: 0.0937 - val_loss: 1.9444 - val_mse: 1.9444 - 85ms/epoch - 85ms/step
# Epoch 1955/2000
# 1/1 - 0s - loss: 0.0454 - mse: 0.0454 - val_loss: 1.2227 - val_mse: 1.2227 - 83ms/epoch - 83ms/step
# Epoch 1956/2000
# 1/1 - 0s - loss: 0.0250 - mse: 0.0250 - val_loss: 1.6061 - val_mse: 1.6061 - 97ms/epoch - 97ms/step
# Epoch 1957/2000
# 1/1 - 0s - loss: 0.0229 - mse: 0.0229 - val_loss: 1.3238 - val_mse: 1.3238 - 93ms/epoch - 93ms/step
# Epoch 1958/2000
# 1/1 - 0s - loss: 0.0288 - mse: 0.0288 - val_loss: 1.6368 - val_mse: 1.6368 - 80ms/epoch - 80ms/step
# Epoch 1959/2000
# 1/1 - 0s - loss: 0.0456 - mse: 0.0456 - val_loss: 1.4022 - val_mse: 1.4022 - 98ms/epoch - 98ms/step
# Epoch 1960/2000
# 1/1 - 0s - loss: 0.0717 - mse: 0.0717 - val_loss: 1.7076 - val_mse: 1.7076 - 72ms/epoch - 72ms/step
# Epoch 1961/2000
# 1/1 - 0s - loss: 0.1120 - mse: 0.1120 - val_loss: 1.3042 - val_mse: 1.3042 - 101ms/epoch - 101ms/step
# Epoch 1962/2000
# 1/1 - 0s - loss: 0.0941 - mse: 0.0941 - val_loss: 1.6260 - val_mse: 1.6260 - 77ms/epoch - 77ms/step
# Epoch 1963/2000
# 1/1 - 0s - loss: 0.0746 - mse: 0.0746 - val_loss: 1.3650 - val_mse: 1.3650 - 72ms/epoch - 72ms/step
# Epoch 1964/2000
# 1/1 - 0s - loss: 0.0761 - mse: 0.0761 - val_loss: 1.5407 - val_mse: 1.5407 - 88ms/epoch - 88ms/step
# Epoch 1965/2000
# 1/1 - 0s - loss: 0.0390 - mse: 0.0390 - val_loss: 1.2548 - val_mse: 1.2548 - 86ms/epoch - 86ms/step
# Epoch 1966/2000
# 1/1 - 0s - loss: 0.0404 - mse: 0.0404 - val_loss: 1.5032 - val_mse: 1.5032 - 78ms/epoch - 78ms/step
# Epoch 1967/2000
# 1/1 - 0s - loss: 0.0364 - mse: 0.0364 - val_loss: 1.2370 - val_mse: 1.2370 - 80ms/epoch - 80ms/step
# Epoch 1968/2000
# 1/1 - 0s - loss: 0.0454 - mse: 0.0454 - val_loss: 1.3905 - val_mse: 1.3905 - 87ms/epoch - 87ms/step
# Epoch 1969/2000
# 1/1 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 1.3211 - val_mse: 1.3211 - 84ms/epoch - 84ms/step
# Epoch 1970/2000
# 1/1 - 0s - loss: 0.0503 - mse: 0.0503 - val_loss: 1.1522 - val_mse: 1.1522 - 90ms/epoch - 90ms/step
# Epoch 1971/2000
# 1/1 - 0s - loss: 0.0706 - mse: 0.0706 - val_loss: 1.7378 - val_mse: 1.7378 - 82ms/epoch - 82ms/step
# Epoch 1972/2000
# 1/1 - 0s - loss: 0.0912 - mse: 0.0912 - val_loss: 0.8762 - val_mse: 0.8762 - 71ms/epoch - 71ms/step
# Epoch 1973/2000
# 1/1 - 0s - loss: 0.1601 - mse: 0.1601 - val_loss: 2.3140 - val_mse: 2.3140 - 81ms/epoch - 81ms/step
# Epoch 1974/2000
# 1/1 - 0s - loss: 0.1489 - mse: 0.1489 - val_loss: 0.8969 - val_mse: 0.8969 - 72ms/epoch - 72ms/step
# Epoch 1975/2000
# 1/1 - 0s - loss: 0.0711 - mse: 0.0711 - val_loss: 1.7068 - val_mse: 1.7068 - 85ms/epoch - 85ms/step
# Epoch 1976/2000
# 1/1 - 0s - loss: 0.0321 - mse: 0.0321 - val_loss: 1.2226 - val_mse: 1.2226 - 80ms/epoch - 80ms/step
# Epoch 1977/2000
# 1/1 - 0s - loss: 0.0315 - mse: 0.0315 - val_loss: 1.6855 - val_mse: 1.6855 - 79ms/epoch - 79ms/step
# Epoch 1978/2000
# 1/1 - 0s - loss: 0.0462 - mse: 0.0462 - val_loss: 1.2839 - val_mse: 1.2839 - 69ms/epoch - 69ms/step
# Epoch 1979/2000
# 1/1 - 0s - loss: 0.0698 - mse: 0.0698 - val_loss: 1.9171 - val_mse: 1.9171 - 79ms/epoch - 79ms/step
# Epoch 1980/2000
# 1/1 - 0s - loss: 0.0971 - mse: 0.0971 - val_loss: 1.2163 - val_mse: 1.2163 - 84ms/epoch - 84ms/step
# Epoch 1981/2000
# 1/1 - 0s - loss: 0.0973 - mse: 0.0973 - val_loss: 1.8618 - val_mse: 1.8618 - 74ms/epoch - 74ms/step
# Epoch 1982/2000
# 1/1 - 0s - loss: 0.0826 - mse: 0.0826 - val_loss: 1.2360 - val_mse: 1.2360 - 91ms/epoch - 91ms/step
# Epoch 1983/2000
# 1/1 - 0s - loss: 0.0714 - mse: 0.0714 - val_loss: 1.6912 - val_mse: 1.6912 - 84ms/epoch - 84ms/step
# Epoch 1984/2000
# 1/1 - 0s - loss: 0.0487 - mse: 0.0487 - val_loss: 1.2652 - val_mse: 1.2652 - 81ms/epoch - 81ms/step
# Epoch 1985/2000
# 1/1 - 0s - loss: 0.0461 - mse: 0.0461 - val_loss: 1.5453 - val_mse: 1.5453 - 74ms/epoch - 74ms/step
# Epoch 1986/2000
# 1/1 - 0s - loss: 0.0361 - mse: 0.0361 - val_loss: 1.2931 - val_mse: 1.2931 - 71ms/epoch - 71ms/step
# Epoch 1987/2000
# 1/1 - 0s - loss: 0.0411 - mse: 0.0411 - val_loss: 1.4143 - val_mse: 1.4143 - 91ms/epoch - 91ms/step
# Epoch 1988/2000
# 1/1 - 0s - loss: 0.0397 - mse: 0.0397 - val_loss: 1.3411 - val_mse: 1.3411 - 77ms/epoch - 77ms/step
# Epoch 1989/2000
# 1/1 - 0s - loss: 0.0510 - mse: 0.0510 - val_loss: 1.2386 - val_mse: 1.2386 - 78ms/epoch - 78ms/step
# Epoch 1990/2000
# 1/1 - 0s - loss: 0.0619 - mse: 0.0619 - val_loss: 1.5010 - val_mse: 1.5010 - 86ms/epoch - 86ms/step
# Epoch 1991/2000
# 1/1 - 0s - loss: 0.0613 - mse: 0.0613 - val_loss: 1.0586 - val_mse: 1.0586 - 95ms/epoch - 95ms/step
# Epoch 1992/2000
# 1/1 - 0s - loss: 0.0936 - mse: 0.0936 - val_loss: 1.9469 - val_mse: 1.9469 - 84ms/epoch - 84ms/step
# Epoch 1993/2000
# 1/1 - 0s - loss: 0.0882 - mse: 0.0882 - val_loss: 0.8397 - val_mse: 0.8397 - 99ms/epoch - 99ms/step
# Epoch 1994/2000
# 1/1 - 0s - loss: 0.0951 - mse: 0.0951 - val_loss: 2.2502 - val_mse: 2.2502 - 95ms/epoch - 95ms/step
# Epoch 1995/2000
# 1/1 - 0s - loss: 0.1093 - mse: 0.1093 - val_loss: 1.0125 - val_mse: 1.0125 - 93ms/epoch - 93ms/step
# Epoch 1996/2000
# 1/1 - 0s - loss: 0.0547 - mse: 0.0547 - val_loss: 1.6540 - val_mse: 1.6540 - 89ms/epoch - 89ms/step
# Epoch 1997/2000
# 1/1 - 0s - loss: 0.0341 - mse: 0.0341 - val_loss: 1.1963 - val_mse: 1.1963 - 83ms/epoch - 83ms/step
# Epoch 1998/2000
# 1/1 - 0s - loss: 0.0274 - mse: 0.0274 - val_loss: 1.6642 - val_mse: 1.6642 - 79ms/epoch - 79ms/step
# Epoch 1999/2000
# 1/1 - 0s - loss: 0.0317 - mse: 0.0317 - val_loss: 1.2926 - val_mse: 1.2926 - 75ms/epoch - 75ms/step
# Epoch 2000/2000
# 1/1 - 0s - loss: 0.0547 - mse: 0.0547 - val_loss: 1.9027 - val_mse: 1.9027 - 87ms/epoch - 87ms/step

# %% [markdown]
# A few comments about the code are in order:
# - In code lines 11-13, we use the parameter “return_sequences=True”, because we want that the used RNN networks return the state sequence at every time sample (in total we have 201 time samples).
# - Then, in code lines 22-24 we say to the compiler that we want to store the model (network parameters) after each epoch. The file names are
# defined according to the validation loss. This has been done in order to retrieve the model with the smallest validation loss. This should be the “best” model, which should be tested using the test data.
# - The commented line 29 loads the model with the best validation loss.
# - In code line 32 we use the test data to generate the predicted output, which is then compared with the “true” test output obtained by simulating the original system.
#
# The following code plots the predicted and “true” test data, and plots the training and validation losses with respect to the training epoch number.

# %%
###############################################################################
#  Plot the predicted and "true" output and plot training and validation losses
###############################################################################
 
# plot the predicted and the "true" (test) outputs
time_plot=range(1,time+2)
plt.figure()
plt.plot(time_plot,testPredict[0,:,0], label='Real output')
plt.plot(time_plot,output_test[0,:],'r', label='Predicted output')
plt.xlabel('Discrete time steps')
plt.ylabel('Output')
plt.legend()
plt.savefig('responseLSTM32.png')
plt.show()
 
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(loss)+1)
plt.figure()
plt.plot(epochs, loss,'b', label='Training loss')
plt.plot(epochs, val_loss,'r', label='Validation loss')
plt.title('Training and validation losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xscale('log')
#plt.yscale('log')
plt.legend()
plt.savefig('lossLSTM32.png')
plt.show()

# %% [markdown]
# try for different number of units. (exercise)

# %% [markdown]
# We can see that we need a relatively high number of units (that is, the model order) to estimate the model. This is due to the two issues. First of all, we need to increase the number of epochs to obtain better results. Secondly, since the model is linear, we need to tell to Keras that we want to use linear activation functions and that we do not need bias. The following code achieves this:

# %%
model=Sequential()
model.add(SimpleRNN(2, input_shape=(trainX.shape[1],trainX.shape[2]),use_bias=False, activation='linear',return_sequences=True))
#model.add(GRU(32, input_shape=(trainX.shape[1],trainX.shape[2]),return_sequences=True))
#model.add(LSTM(32, input_shape=(trainX.shape[1],trainX.shape[2]),return_sequences=True))
#model.add(Dense(1))
 
model.add(Dense(1, activation='linear', use_bias=False))
#model.add(TimeDistributed(Dense(1,activation="linear",use_bias=False)))  #there is no difference between this and model.add(Dense(1))...
# does not make sense to use metrics=['acc'], see https://stackoverflow.com/questions/41819457/zero-accuracy-training-a-neural-network-in-keras
model.compile(optimizer=RMSprop(), loss='mean_squared_error', metrics=['mse'])
# after every epoch, we save the model, this is the absolute path on my C: drive, so the path is
# C:\python_files\system_identification\models\
filepath="\\python_files\\system_identification\\models\\weights-{epoch:02d}-{val_loss:.6f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)
callbacks_list = [checkpoint]
history=model.fit(trainX, output_train , epochs=4000, batch_size=1, callbacks=callbacks_list, validation_data=(validateX,output_validate), verbose=2)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 1501/4000
# 1/1 - 0s - loss: 2.5846 - mse: 2.5846 - val_loss: 5.5036 - val_mse: 5.5036 - 183ms/epoch - 183ms/step
# Epoch 1502/4000
# 1/1 - 0s - loss: 2.5847 - mse: 2.5847 - val_loss: 5.5077 - val_mse: 5.5077 - 171ms/epoch - 171ms/step
# Epoch 1503/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5034 - val_mse: 5.5034 - 184ms/epoch - 184ms/step
# Epoch 1504/4000
# 1/1 - 0s - loss: 2.5847 - mse: 2.5847 - val_loss: 5.5075 - val_mse: 5.5075 - 167ms/epoch - 167ms/step
# Epoch 1505/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5032 - val_mse: 5.5032 - 182ms/epoch - 182ms/step
# Epoch 1506/4000
# 1/1 - 0s - loss: 2.5847 - mse: 2.5847 - val_loss: 5.5073 - val_mse: 5.5073 - 191ms/epoch - 191ms/step
# Epoch 1507/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5031 - val_mse: 5.5031 - 181ms/epoch - 181ms/step
# Epoch 1508/4000
# 1/1 - 0s - loss: 2.5847 - mse: 2.5847 - val_loss: 5.5072 - val_mse: 5.5072 - 183ms/epoch - 183ms/step
# Epoch 1509/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5029 - val_mse: 5.5029 - 185ms/epoch - 185ms/step
# Epoch 1510/4000
# 1/1 - 0s - loss: 2.5846 - mse: 2.5846 - val_loss: 5.5070 - val_mse: 5.5070 - 166ms/epoch - 166ms/step
# Epoch 1511/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5027 - val_mse: 5.5027 - 191ms/epoch - 191ms/step
# Epoch 1512/4000
# 1/1 - 0s - loss: 2.5846 - mse: 2.5846 - val_loss: 5.5068 - val_mse: 5.5068 - 188ms/epoch - 188ms/step
# Epoch 1513/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5025 - val_mse: 5.5025 - 195ms/epoch - 195ms/step
# Epoch 1514/4000
# 1/1 - 0s - loss: 2.5846 - mse: 2.5846 - val_loss: 5.5067 - val_mse: 5.5067 - 173ms/epoch - 173ms/step
# Epoch 1515/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5024 - val_mse: 5.5024 - 200ms/epoch - 200ms/step
# Epoch 1516/4000
# 1/1 - 0s - loss: 2.5846 - mse: 2.5846 - val_loss: 5.5065 - val_mse: 5.5065 - 167ms/epoch - 167ms/step
# Epoch 1517/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5022 - val_mse: 5.5022 - 212ms/epoch - 212ms/step
# Epoch 1518/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5063 - val_mse: 5.5063 - 177ms/epoch - 177ms/step
# Epoch 1519/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5020 - val_mse: 5.5020 - 192ms/epoch - 192ms/step
# Epoch 1520/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5062 - val_mse: 5.5062 - 168ms/epoch - 168ms/step
# Epoch 1521/4000
# 1/1 - 0s - loss: 2.5843 - mse: 2.5843 - val_loss: 5.5019 - val_mse: 5.5019 - 195ms/epoch - 195ms/step
# Epoch 1522/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5060 - val_mse: 5.5060 - 186ms/epoch - 186ms/step
# Epoch 1523/4000
# 1/1 - 0s - loss: 2.5843 - mse: 2.5843 - val_loss: 5.5017 - val_mse: 5.5017 - 195ms/epoch - 195ms/step
# Epoch 1524/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5058 - val_mse: 5.5058 - 169ms/epoch - 169ms/step
# Epoch 1525/4000
# 1/1 - 0s - loss: 2.5843 - mse: 2.5843 - val_loss: 5.5015 - val_mse: 5.5015 - 178ms/epoch - 178ms/step
# Epoch 1526/4000
# 1/1 - 0s - loss: 2.5845 - mse: 2.5845 - val_loss: 5.5057 - val_mse: 5.5057 - 186ms/epoch - 186ms/step
# Epoch 1527/4000
# 1/1 - 0s - loss: 2.5843 - mse: 2.5843 - val_loss: 5.5014 - val_mse: 5.5014 - 204ms/epoch - 204ms/step
# Epoch 1528/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5055 - val_mse: 5.5055 - 177ms/epoch - 177ms/step
# Epoch 1529/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5012 - val_mse: 5.5012 - 197ms/epoch - 197ms/step
# Epoch 1530/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5054 - val_mse: 5.5054 - 176ms/epoch - 176ms/step
# Epoch 1531/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5010 - val_mse: 5.5010 - 191ms/epoch - 191ms/step
# Epoch 1532/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5052 - val_mse: 5.5052 - 185ms/epoch - 185ms/step
# Epoch 1533/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5009 - val_mse: 5.5009 - 191ms/epoch - 191ms/step
# Epoch 1534/4000
# 1/1 - 0s - loss: 2.5844 - mse: 2.5844 - val_loss: 5.5050 - val_mse: 5.5050 - 175ms/epoch - 175ms/step
# Epoch 1535/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5007 - val_mse: 5.5007 - 183ms/epoch - 183ms/step
# Epoch 1536/4000
# 1/1 - 0s - loss: 2.5843 - mse: 2.5843 - val_loss: 5.5049 - val_mse: 5.5049 - 164ms/epoch - 164ms/step
# Epoch 1537/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.5005 - val_mse: 5.5005 - 191ms/epoch - 191ms/step
# Epoch 1538/4000
# 1/1 - 0s - loss: 2.5843 - mse: 2.5843 - val_loss: 5.5047 - val_mse: 5.5047 - 183ms/epoch - 183ms/step
# Epoch 1539/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.5004 - val_mse: 5.5004 - 185ms/epoch - 185ms/step
# Epoch 1540/4000
# 1/1 - 0s - loss: 2.5843 - mse: 2.5843 - val_loss: 5.5045 - val_mse: 5.5045 - 171ms/epoch - 171ms/step
# Epoch 1541/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.5002 - val_mse: 5.5002 - 179ms/epoch - 179ms/step
# Epoch 1542/4000
# 1/1 - 0s - loss: 2.5843 - mse: 2.5843 - val_loss: 5.5044 - val_mse: 5.5044 - 182ms/epoch - 182ms/step
# Epoch 1543/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.5000 - val_mse: 5.5000 - 207ms/epoch - 207ms/step
# Epoch 1544/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5042 - val_mse: 5.5042 - 185ms/epoch - 185ms/step
# Epoch 1545/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.4999 - val_mse: 5.4999 - 189ms/epoch - 189ms/step
# Epoch 1546/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5041 - val_mse: 5.5041 - 171ms/epoch - 171ms/step
# Epoch 1547/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.4997 - val_mse: 5.4997 - 180ms/epoch - 180ms/step
# Epoch 1548/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5039 - val_mse: 5.5039 - 216ms/epoch - 216ms/step
# Epoch 1549/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.4995 - val_mse: 5.4995 - 195ms/epoch - 195ms/step
# Epoch 1550/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5037 - val_mse: 5.5037 - 173ms/epoch - 173ms/step
# Epoch 1551/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.4994 - val_mse: 5.4994 - 179ms/epoch - 179ms/step
# Epoch 1552/4000
# 1/1 - 0s - loss: 2.5842 - mse: 2.5842 - val_loss: 5.5036 - val_mse: 5.5036 - 175ms/epoch - 175ms/step
# Epoch 1553/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.4992 - val_mse: 5.4992 - 195ms/epoch - 195ms/step
# Epoch 1554/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.5034 - val_mse: 5.5034 - 166ms/epoch - 166ms/step
# Epoch 1555/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.4990 - val_mse: 5.4990 - 189ms/epoch - 189ms/step
# Epoch 1556/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.5033 - val_mse: 5.5033 - 170ms/epoch - 170ms/step
# Epoch 1557/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.4989 - val_mse: 5.4989 - 187ms/epoch - 187ms/step
# Epoch 1558/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.5031 - val_mse: 5.5031 - 167ms/epoch - 167ms/step
# Epoch 1559/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.4987 - val_mse: 5.4987 - 201ms/epoch - 201ms/step
# Epoch 1560/4000
# 1/1 - 0s - loss: 2.5841 - mse: 2.5841 - val_loss: 5.5029 - val_mse: 5.5029 - 177ms/epoch - 177ms/step
# Epoch 1561/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.4986 - val_mse: 5.4986 - 188ms/epoch - 188ms/step
# Epoch 1562/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.5028 - val_mse: 5.5028 - 182ms/epoch - 182ms/step
# Epoch 1563/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.4984 - val_mse: 5.4984 - 191ms/epoch - 191ms/step
# Epoch 1564/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.5026 - val_mse: 5.5026 - 193ms/epoch - 193ms/step
# Epoch 1565/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.4982 - val_mse: 5.4982 - 197ms/epoch - 197ms/step
# Epoch 1566/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.5025 - val_mse: 5.5025 - 182ms/epoch - 182ms/step
# Epoch 1567/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.4981 - val_mse: 5.4981 - 200ms/epoch - 200ms/step
# Epoch 1568/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.5023 - val_mse: 5.5023 - 174ms/epoch - 174ms/step
# Epoch 1569/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.4979 - val_mse: 5.4979 - 213ms/epoch - 213ms/step
# Epoch 1570/4000
# 1/1 - 0s - loss: 2.5840 - mse: 2.5840 - val_loss: 5.5021 - val_mse: 5.5021 - 176ms/epoch - 176ms/step
# Epoch 1571/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.4977 - val_mse: 5.4977 - 182ms/epoch - 182ms/step
# Epoch 1572/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.5020 - val_mse: 5.5020 - 178ms/epoch - 178ms/step
# Epoch 1573/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.4976 - val_mse: 5.4976 - 198ms/epoch - 198ms/step
# Epoch 1574/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.5018 - val_mse: 5.5018 - 155ms/epoch - 155ms/step
# Epoch 1575/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.4974 - val_mse: 5.4974 - 199ms/epoch - 199ms/step
# Epoch 1576/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.5017 - val_mse: 5.5017 - 160ms/epoch - 160ms/step
# Epoch 1577/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.4973 - val_mse: 5.4973 - 183ms/epoch - 183ms/step
# Epoch 1578/4000
# 1/1 - 0s - loss: 2.5839 - mse: 2.5839 - val_loss: 5.5015 - val_mse: 5.5015 - 165ms/epoch - 165ms/step
# Epoch 1579/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.4971 - val_mse: 5.4971 - 190ms/epoch - 190ms/step
# Epoch 1580/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.5014 - val_mse: 5.5014 - 172ms/epoch - 172ms/step
# Epoch 1581/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.4969 - val_mse: 5.4969 - 197ms/epoch - 197ms/step
# Epoch 1582/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.5012 - val_mse: 5.5012 - 157ms/epoch - 157ms/step
# Epoch 1583/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.4968 - val_mse: 5.4968 - 186ms/epoch - 186ms/step
# Epoch 1584/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.5010 - val_mse: 5.5010 - 168ms/epoch - 168ms/step
# Epoch 1585/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.4966 - val_mse: 5.4966 - 181ms/epoch - 181ms/step
# Epoch 1586/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.5009 - val_mse: 5.5009 - 184ms/epoch - 184ms/step
# Epoch 1587/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.4965 - val_mse: 5.4965 - 185ms/epoch - 185ms/step
# Epoch 1588/4000
# 1/1 - 0s - loss: 2.5838 - mse: 2.5838 - val_loss: 5.5007 - val_mse: 5.5007 - 179ms/epoch - 179ms/step
# Epoch 1589/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.4963 - val_mse: 5.4963 - 202ms/epoch - 202ms/step
# Epoch 1590/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.5006 - val_mse: 5.5006 - 173ms/epoch - 173ms/step
# Epoch 1591/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4961 - val_mse: 5.4961 - 187ms/epoch - 187ms/step
# Epoch 1592/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.5004 - val_mse: 5.5004 - 163ms/epoch - 163ms/step
# Epoch 1593/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4960 - val_mse: 5.4960 - 191ms/epoch - 191ms/step
# Epoch 1594/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.5003 - val_mse: 5.5003 - 171ms/epoch - 171ms/step
# Epoch 1595/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4958 - val_mse: 5.4958 - 203ms/epoch - 203ms/step
# Epoch 1596/4000
# 1/1 - 0s - loss: 2.5837 - mse: 2.5837 - val_loss: 5.5001 - val_mse: 5.5001 - 180ms/epoch - 180ms/step
# Epoch 1597/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4957 - val_mse: 5.4957 - 190ms/epoch - 190ms/step
# Epoch 1598/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.5000 - val_mse: 5.5000 - 164ms/epoch - 164ms/step
# Epoch 1599/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4955 - val_mse: 5.4955 - 186ms/epoch - 186ms/step
# Epoch 1600/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.4998 - val_mse: 5.4998 - 167ms/epoch - 167ms/step
# Epoch 1601/4000
# 1/1 - 0s - loss: 2.5834 - mse: 2.5834 - val_loss: 5.4954 - val_mse: 5.4954 - 184ms/epoch - 184ms/step
# Epoch 1602/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.4997 - val_mse: 5.4997 - 171ms/epoch - 171ms/step
# Epoch 1603/4000
# 1/1 - 0s - loss: 2.5834 - mse: 2.5834 - val_loss: 5.4952 - val_mse: 5.4952 - 194ms/epoch - 194ms/step
# Epoch 1604/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.4995 - val_mse: 5.4995 - 193ms/epoch - 193ms/step
# Epoch 1605/4000
# 1/1 - 0s - loss: 2.5834 - mse: 2.5834 - val_loss: 5.4950 - val_mse: 5.4950 - 202ms/epoch - 202ms/step
# Epoch 1606/4000
# 1/1 - 0s - loss: 2.5836 - mse: 2.5836 - val_loss: 5.4994 - val_mse: 5.4994 - 173ms/epoch - 173ms/step
# Epoch 1607/4000
# 1/1 - 0s - loss: 2.5834 - mse: 2.5834 - val_loss: 5.4949 - val_mse: 5.4949 - 198ms/epoch - 198ms/step
# Epoch 1608/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4992 - val_mse: 5.4992 - 161ms/epoch - 161ms/step
# Epoch 1609/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4947 - val_mse: 5.4947 - 184ms/epoch - 184ms/step
# Epoch 1610/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4991 - val_mse: 5.4991 - 176ms/epoch - 176ms/step
# Epoch 1611/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4946 - val_mse: 5.4946 - 185ms/epoch - 185ms/step
# Epoch 1612/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4989 - val_mse: 5.4989 - 180ms/epoch - 180ms/step
# Epoch 1613/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4944 - val_mse: 5.4944 - 194ms/epoch - 194ms/step
# Epoch 1614/4000
# 1/1 - 0s - loss: 2.5835 - mse: 2.5835 - val_loss: 5.4988 - val_mse: 5.4988 - 184ms/epoch - 184ms/step
# Epoch 1615/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4943 - val_mse: 5.4943 - 191ms/epoch - 191ms/step
# Epoch 1616/4000
# 1/1 - 0s - loss: 2.5834 - mse: 2.5834 - val_loss: 5.4986 - val_mse: 5.4986 - 161ms/epoch - 161ms/step
# Epoch 1617/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4941 - val_mse: 5.4941 - 193ms/epoch - 193ms/step
# Epoch 1618/4000
# 1/1 - 0s - loss: 2.5834 - mse: 2.5834 - val_loss: 5.4985 - val_mse: 5.4985 - 184ms/epoch - 184ms/step
# Epoch 1619/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4940 - val_mse: 5.4940 - 176ms/epoch - 176ms/step
# Epoch 1620/4000
# 1/1 - 0s - loss: 2.5834 - mse: 2.5834 - val_loss: 5.4983 - val_mse: 5.4983 - 164ms/epoch - 164ms/step
# Epoch 1621/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4938 - val_mse: 5.4938 - 208ms/epoch - 208ms/step
# Epoch 1622/4000
# 1/1 - 0s - loss: 2.5834 - mse: 2.5834 - val_loss: 5.4982 - val_mse: 5.4982 - 181ms/epoch - 181ms/step
# Epoch 1623/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4937 - val_mse: 5.4937 - 188ms/epoch - 188ms/step
# Epoch 1624/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4980 - val_mse: 5.4980 - 161ms/epoch - 161ms/step
# Epoch 1625/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4935 - val_mse: 5.4935 - 200ms/epoch - 200ms/step
# Epoch 1626/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4979 - val_mse: 5.4979 - 166ms/epoch - 166ms/step
# Epoch 1627/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4933 - val_mse: 5.4933 - 185ms/epoch - 185ms/step
# Epoch 1628/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4977 - val_mse: 5.4977 - 181ms/epoch - 181ms/step
# Epoch 1629/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4932 - val_mse: 5.4932 - 195ms/epoch - 195ms/step
# Epoch 1630/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4976 - val_mse: 5.4976 - 172ms/epoch - 172ms/step
# Epoch 1631/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4930 - val_mse: 5.4930 - 183ms/epoch - 183ms/step
# Epoch 1632/4000
# 1/1 - 0s - loss: 2.5833 - mse: 2.5833 - val_loss: 5.4974 - val_mse: 5.4974 - 164ms/epoch - 164ms/step
# Epoch 1633/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4929 - val_mse: 5.4929 - 186ms/epoch - 186ms/step
# Epoch 1634/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4973 - val_mse: 5.4973 - 183ms/epoch - 183ms/step
# Epoch 1635/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4927 - val_mse: 5.4927 - 193ms/epoch - 193ms/step
# Epoch 1636/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4971 - val_mse: 5.4971 - 175ms/epoch - 175ms/step
# Epoch 1637/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4926 - val_mse: 5.4926 - 192ms/epoch - 192ms/step
# Epoch 1638/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4970 - val_mse: 5.4970 - 172ms/epoch - 172ms/step
# Epoch 1639/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4924 - val_mse: 5.4924 - 203ms/epoch - 203ms/step
# Epoch 1640/4000
# 1/1 - 0s - loss: 2.5832 - mse: 2.5832 - val_loss: 5.4968 - val_mse: 5.4968 - 188ms/epoch - 188ms/step
# Epoch 1641/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4923 - val_mse: 5.4923 - 193ms/epoch - 193ms/step
# Epoch 1642/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4967 - val_mse: 5.4967 - 170ms/epoch - 170ms/step
# Epoch 1643/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4921 - val_mse: 5.4921 - 194ms/epoch - 194ms/step
# Epoch 1644/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4965 - val_mse: 5.4965 - 189ms/epoch - 189ms/step
# Epoch 1645/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4920 - val_mse: 5.4920 - 178ms/epoch - 178ms/step
# Epoch 1646/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4964 - val_mse: 5.4964 - 186ms/epoch - 186ms/step
# Epoch 1647/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4918 - val_mse: 5.4918 - 197ms/epoch - 197ms/step
# Epoch 1648/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4962 - val_mse: 5.4962 - 180ms/epoch - 180ms/step
# Epoch 1649/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4917 - val_mse: 5.4917 - 198ms/epoch - 198ms/step
# Epoch 1650/4000
# 1/1 - 0s - loss: 2.5831 - mse: 2.5831 - val_loss: 5.4961 - val_mse: 5.4961 - 177ms/epoch - 177ms/step
# Epoch 1651/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4915 - val_mse: 5.4915 - 189ms/epoch - 189ms/step
# Epoch 1652/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4960 - val_mse: 5.4960 - 182ms/epoch - 182ms/step
# Epoch 1653/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4914 - val_mse: 5.4914 - 187ms/epoch - 187ms/step
# Epoch 1654/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4958 - val_mse: 5.4958 - 175ms/epoch - 175ms/step
# Epoch 1655/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4912 - val_mse: 5.4912 - 204ms/epoch - 204ms/step
# Epoch 1656/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4957 - val_mse: 5.4957 - 175ms/epoch - 175ms/step
# Epoch 1657/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4911 - val_mse: 5.4911 - 188ms/epoch - 188ms/step
# Epoch 1658/4000
# 1/1 - 0s - loss: 2.5830 - mse: 2.5830 - val_loss: 5.4955 - val_mse: 5.4955 - 173ms/epoch - 173ms/step
# Epoch 1659/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4909 - val_mse: 5.4909 - 186ms/epoch - 186ms/step
# Epoch 1660/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4954 - val_mse: 5.4954 - 180ms/epoch - 180ms/step
# Epoch 1661/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4908 - val_mse: 5.4908 - 182ms/epoch - 182ms/step
# Epoch 1662/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4952 - val_mse: 5.4952 - 176ms/epoch - 176ms/step
# Epoch 1663/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4906 - val_mse: 5.4906 - 190ms/epoch - 190ms/step
# Epoch 1664/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4951 - val_mse: 5.4951 - 166ms/epoch - 166ms/step
# Epoch 1665/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4905 - val_mse: 5.4905 - 200ms/epoch - 200ms/step
# Epoch 1666/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4950 - val_mse: 5.4950 - 168ms/epoch - 168ms/step
# Epoch 1667/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4904 - val_mse: 5.4904 - 192ms/epoch - 192ms/step
# Epoch 1668/4000
# 1/1 - 0s - loss: 2.5829 - mse: 2.5829 - val_loss: 5.4948 - val_mse: 5.4948 - 189ms/epoch - 189ms/step
# Epoch 1669/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4902 - val_mse: 5.4902 - 185ms/epoch - 185ms/step
# Epoch 1670/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4947 - val_mse: 5.4947 - 196ms/epoch - 196ms/step
# Epoch 1671/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4901 - val_mse: 5.4901 - 195ms/epoch - 195ms/step
# Epoch 1672/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4945 - val_mse: 5.4945 - 183ms/epoch - 183ms/step
# Epoch 1673/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4899 - val_mse: 5.4899 - 187ms/epoch - 187ms/step
# Epoch 1674/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4944 - val_mse: 5.4944 - 184ms/epoch - 184ms/step
# Epoch 1675/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4898 - val_mse: 5.4898 - 199ms/epoch - 199ms/step
# Epoch 1676/4000
# 1/1 - 0s - loss: 2.5828 - mse: 2.5828 - val_loss: 5.4942 - val_mse: 5.4942 - 196ms/epoch - 196ms/step
# Epoch 1677/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4896 - val_mse: 5.4896 - 200ms/epoch - 200ms/step
# Epoch 1678/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4941 - val_mse: 5.4941 - 181ms/epoch - 181ms/step
# Epoch 1679/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4895 - val_mse: 5.4895 - 193ms/epoch - 193ms/step
# Epoch 1680/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4940 - val_mse: 5.4940 - 178ms/epoch - 178ms/step
# Epoch 1681/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4893 - val_mse: 5.4893 - 197ms/epoch - 197ms/step
# Epoch 1682/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4938 - val_mse: 5.4938 - 169ms/epoch - 169ms/step
# Epoch 1683/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4892 - val_mse: 5.4892 - 194ms/epoch - 194ms/step
# Epoch 1684/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4937 - val_mse: 5.4937 - 172ms/epoch - 172ms/step
# Epoch 1685/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4890 - val_mse: 5.4890 - 182ms/epoch - 182ms/step
# Epoch 1686/4000
# 1/1 - 0s - loss: 2.5827 - mse: 2.5827 - val_loss: 5.4935 - val_mse: 5.4935 - 179ms/epoch - 179ms/step
# Epoch 1687/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4889 - val_mse: 5.4889 - 178ms/epoch - 178ms/step
# Epoch 1688/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4934 - val_mse: 5.4934 - 180ms/epoch - 180ms/step
# Epoch 1689/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4888 - val_mse: 5.4888 - 187ms/epoch - 187ms/step
# Epoch 1690/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4933 - val_mse: 5.4933 - 174ms/epoch - 174ms/step
# Epoch 1691/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4886 - val_mse: 5.4886 - 197ms/epoch - 197ms/step
# Epoch 1692/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4931 - val_mse: 5.4931 - 180ms/epoch - 180ms/step
# Epoch 1693/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4885 - val_mse: 5.4885 - 188ms/epoch - 188ms/step
# Epoch 1694/4000
# 1/1 - 0s - loss: 2.5826 - mse: 2.5826 - val_loss: 5.4930 - val_mse: 5.4930 - 165ms/epoch - 165ms/step
# Epoch 1695/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4883 - val_mse: 5.4883 - 191ms/epoch - 191ms/step
# Epoch 1696/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4929 - val_mse: 5.4929 - 164ms/epoch - 164ms/step
# Epoch 1697/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4882 - val_mse: 5.4882 - 198ms/epoch - 198ms/step
# Epoch 1698/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4927 - val_mse: 5.4927 - 167ms/epoch - 167ms/step
# Epoch 1699/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4880 - val_mse: 5.4880 - 182ms/epoch - 182ms/step
# Epoch 1700/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4926 - val_mse: 5.4926 - 166ms/epoch - 166ms/step
# Epoch 1701/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4879 - val_mse: 5.4879 - 175ms/epoch - 175ms/step
# Epoch 1702/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4924 - val_mse: 5.4924 - 195ms/epoch - 195ms/step
# Epoch 1703/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4878 - val_mse: 5.4878 - 182ms/epoch - 182ms/step
# Epoch 1704/4000
# 1/1 - 0s - loss: 2.5825 - mse: 2.5825 - val_loss: 5.4923 - val_mse: 5.4923 - 183ms/epoch - 183ms/step
# Epoch 1705/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4876 - val_mse: 5.4876 - 180ms/epoch - 180ms/step
# Epoch 1706/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4922 - val_mse: 5.4922 - 174ms/epoch - 174ms/step
# Epoch 1707/4000
# 1/1 - 0s - loss: 2.5822 - mse: 2.5822 - val_loss: 5.4875 - val_mse: 5.4875 - 197ms/epoch - 197ms/step
# Epoch 1708/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4920 - val_mse: 5.4920 - 176ms/epoch - 176ms/step
# Epoch 1709/4000
# 1/1 - 0s - loss: 2.5822 - mse: 2.5822 - val_loss: 5.4873 - val_mse: 5.4873 - 233ms/epoch - 233ms/step
# Epoch 1710/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4919 - val_mse: 5.4919 - 174ms/epoch - 174ms/step
# Epoch 1711/4000
# 1/1 - 0s - loss: 2.5822 - mse: 2.5822 - val_loss: 5.4872 - val_mse: 5.4872 - 200ms/epoch - 200ms/step
# Epoch 1712/4000
# 1/1 - 0s - loss: 2.5824 - mse: 2.5824 - val_loss: 5.4918 - val_mse: 5.4918 - 171ms/epoch - 171ms/step
# Epoch 1713/4000
# 1/1 - 0s - loss: 2.5822 - mse: 2.5822 - val_loss: 5.4871 - val_mse: 5.4871 - 207ms/epoch - 207ms/step
# Epoch 1714/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4916 - val_mse: 5.4916 - 170ms/epoch - 170ms/step
# Epoch 1715/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4869 - val_mse: 5.4869 - 193ms/epoch - 193ms/step
# Epoch 1716/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4915 - val_mse: 5.4915 - 186ms/epoch - 186ms/step
# Epoch 1717/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4868 - val_mse: 5.4868 - 196ms/epoch - 196ms/step
# Epoch 1718/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4914 - val_mse: 5.4914 - 199ms/epoch - 199ms/step
# Epoch 1719/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4866 - val_mse: 5.4866 - 192ms/epoch - 192ms/step
# Epoch 1720/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4912 - val_mse: 5.4912 - 173ms/epoch - 173ms/step
# Epoch 1721/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4865 - val_mse: 5.4865 - 180ms/epoch - 180ms/step
# Epoch 1722/4000
# 1/1 - 0s - loss: 2.5823 - mse: 2.5823 - val_loss: 5.4911 - val_mse: 5.4911 - 167ms/epoch - 167ms/step
# Epoch 1723/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4864 - val_mse: 5.4864 - 192ms/epoch - 192ms/step
# Epoch 1724/4000
# 1/1 - 0s - loss: 2.5822 - mse: 2.5822 - val_loss: 5.4910 - val_mse: 5.4910 - 165ms/epoch - 165ms/step
# Epoch 1725/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4862 - val_mse: 5.4862 - 183ms/epoch - 183ms/step
# Epoch 1726/4000
# 1/1 - 0s - loss: 2.5822 - mse: 2.5822 - val_loss: 5.4908 - val_mse: 5.4908 - 176ms/epoch - 176ms/step
# Epoch 1727/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4861 - val_mse: 5.4861 - 195ms/epoch - 195ms/step
# Epoch 1728/4000
# 1/1 - 0s - loss: 2.5822 - mse: 2.5822 - val_loss: 5.4907 - val_mse: 5.4907 - 217ms/epoch - 217ms/step
# Epoch 1729/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4859 - val_mse: 5.4859 - 199ms/epoch - 199ms/step
# Epoch 1730/4000
# 1/1 - 0s - loss: 2.5822 - mse: 2.5822 - val_loss: 5.4906 - val_mse: 5.4906 - 180ms/epoch - 180ms/step
# Epoch 1731/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4858 - val_mse: 5.4858 - 196ms/epoch - 196ms/step
# Epoch 1732/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4904 - val_mse: 5.4904 - 177ms/epoch - 177ms/step
# Epoch 1733/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4857 - val_mse: 5.4857 - 193ms/epoch - 193ms/step
# Epoch 1734/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4903 - val_mse: 5.4903 - 180ms/epoch - 180ms/step
# Epoch 1735/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4855 - val_mse: 5.4855 - 191ms/epoch - 191ms/step
# Epoch 1736/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4902 - val_mse: 5.4902 - 163ms/epoch - 163ms/step
# Epoch 1737/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4854 - val_mse: 5.4854 - 187ms/epoch - 187ms/step
# Epoch 1738/4000
# 1/1 - 0s - loss: 2.5821 - mse: 2.5821 - val_loss: 5.4900 - val_mse: 5.4900 - 170ms/epoch - 170ms/step
# Epoch 1739/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4853 - val_mse: 5.4853 - 204ms/epoch - 204ms/step
# Epoch 1740/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4899 - val_mse: 5.4899 - 179ms/epoch - 179ms/step
# Epoch 1741/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4851 - val_mse: 5.4851 - 193ms/epoch - 193ms/step
# Epoch 1742/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4898 - val_mse: 5.4898 - 177ms/epoch - 177ms/step
# Epoch 1743/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4850 - val_mse: 5.4850 - 186ms/epoch - 186ms/step
# Epoch 1744/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4896 - val_mse: 5.4896 - 193ms/epoch - 193ms/step
# Epoch 1745/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4849 - val_mse: 5.4849 - 235ms/epoch - 235ms/step
# Epoch 1746/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4895 - val_mse: 5.4895 - 171ms/epoch - 171ms/step
# Epoch 1747/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4847 - val_mse: 5.4847 - 186ms/epoch - 186ms/step
# Epoch 1748/4000
# 1/1 - 0s - loss: 2.5820 - mse: 2.5820 - val_loss: 5.4894 - val_mse: 5.4894 - 165ms/epoch - 165ms/step
# Epoch 1749/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4846 - val_mse: 5.4846 - 197ms/epoch - 197ms/step
# Epoch 1750/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4892 - val_mse: 5.4892 - 172ms/epoch - 172ms/step
# Epoch 1751/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4844 - val_mse: 5.4844 - 185ms/epoch - 185ms/step
# Epoch 1752/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4891 - val_mse: 5.4891 - 168ms/epoch - 168ms/step
# Epoch 1753/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4843 - val_mse: 5.4843 - 179ms/epoch - 179ms/step
# Epoch 1754/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4890 - val_mse: 5.4890 - 173ms/epoch - 173ms/step
# Epoch 1755/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4842 - val_mse: 5.4842 - 204ms/epoch - 204ms/step
# Epoch 1756/4000
# 1/1 - 0s - loss: 2.5819 - mse: 2.5819 - val_loss: 5.4889 - val_mse: 5.4889 - 174ms/epoch - 174ms/step
# Epoch 1757/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4840 - val_mse: 5.4840 - 191ms/epoch - 191ms/step
# Epoch 1758/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4887 - val_mse: 5.4887 - 174ms/epoch - 174ms/step
# Epoch 1759/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4839 - val_mse: 5.4839 - 185ms/epoch - 185ms/step
# Epoch 1760/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4886 - val_mse: 5.4886 - 188ms/epoch - 188ms/step
# Epoch 1761/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4838 - val_mse: 5.4838 - 178ms/epoch - 178ms/step
# Epoch 1762/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4885 - val_mse: 5.4885 - 166ms/epoch - 166ms/step
# Epoch 1763/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4836 - val_mse: 5.4836 - 191ms/epoch - 191ms/step
# Epoch 1764/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4883 - val_mse: 5.4883 - 169ms/epoch - 169ms/step
# Epoch 1765/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4835 - val_mse: 5.4835 - 196ms/epoch - 196ms/step
# Epoch 1766/4000
# 1/1 - 0s - loss: 2.5818 - mse: 2.5818 - val_loss: 5.4882 - val_mse: 5.4882 - 170ms/epoch - 170ms/step
# Epoch 1767/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4834 - val_mse: 5.4834 - 192ms/epoch - 192ms/step
# Epoch 1768/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4881 - val_mse: 5.4881 - 172ms/epoch - 172ms/step
# Epoch 1769/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4833 - val_mse: 5.4833 - 196ms/epoch - 196ms/step
# Epoch 1770/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4880 - val_mse: 5.4880 - 173ms/epoch - 173ms/step
# Epoch 1771/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4831 - val_mse: 5.4831 - 196ms/epoch - 196ms/step
# Epoch 1772/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4878 - val_mse: 5.4878 - 172ms/epoch - 172ms/step
# Epoch 1773/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4830 - val_mse: 5.4830 - 186ms/epoch - 186ms/step
# Epoch 1774/4000
# 1/1 - 0s - loss: 2.5817 - mse: 2.5817 - val_loss: 5.4877 - val_mse: 5.4877 - 186ms/epoch - 186ms/step
# Epoch 1775/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4829 - val_mse: 5.4829 - 196ms/epoch - 196ms/step
# Epoch 1776/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4876 - val_mse: 5.4876 - 191ms/epoch - 191ms/step
# Epoch 1777/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4827 - val_mse: 5.4827 - 190ms/epoch - 190ms/step
# Epoch 1778/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4875 - val_mse: 5.4875 - 174ms/epoch - 174ms/step
# Epoch 1779/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4826 - val_mse: 5.4826 - 188ms/epoch - 188ms/step
# Epoch 1780/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4873 - val_mse: 5.4873 - 185ms/epoch - 185ms/step
# Epoch 1781/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4825 - val_mse: 5.4825 - 204ms/epoch - 204ms/step
# Epoch 1782/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4872 - val_mse: 5.4872 - 169ms/epoch - 169ms/step
# Epoch 1783/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4823 - val_mse: 5.4823 - 187ms/epoch - 187ms/step
# Epoch 1784/4000
# 1/1 - 0s - loss: 2.5816 - mse: 2.5816 - val_loss: 5.4871 - val_mse: 5.4871 - 186ms/epoch - 186ms/step
# Epoch 1785/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4822 - val_mse: 5.4822 - 193ms/epoch - 193ms/step
# Epoch 1786/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4870 - val_mse: 5.4870 - 181ms/epoch - 181ms/step
# Epoch 1787/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4821 - val_mse: 5.4821 - 197ms/epoch - 197ms/step
# Epoch 1788/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4868 - val_mse: 5.4868 - 180ms/epoch - 180ms/step
# Epoch 1789/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4820 - val_mse: 5.4820 - 194ms/epoch - 194ms/step
# Epoch 1790/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4867 - val_mse: 5.4867 - 163ms/epoch - 163ms/step
# Epoch 1791/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4818 - val_mse: 5.4818 - 187ms/epoch - 187ms/step
# Epoch 1792/4000
# 1/1 - 0s - loss: 2.5815 - mse: 2.5815 - val_loss: 5.4866 - val_mse: 5.4866 - 179ms/epoch - 179ms/step
# Epoch 1793/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4817 - val_mse: 5.4817 - 190ms/epoch - 190ms/step
# Epoch 1794/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4865 - val_mse: 5.4865 - 171ms/epoch - 171ms/step
# Epoch 1795/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4816 - val_mse: 5.4816 - 191ms/epoch - 191ms/step
# Epoch 1796/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4863 - val_mse: 5.4863 - 166ms/epoch - 166ms/step
# Epoch 1797/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4814 - val_mse: 5.4814 - 201ms/epoch - 201ms/step
# Epoch 1798/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4862 - val_mse: 5.4862 - 178ms/epoch - 178ms/step
# Epoch 1799/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4813 - val_mse: 5.4813 - 233ms/epoch - 233ms/step
# Epoch 1800/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4861 - val_mse: 5.4861 - 178ms/epoch - 178ms/step
# Epoch 1801/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4812 - val_mse: 5.4812 - 192ms/epoch - 192ms/step
# Epoch 1802/4000
# 1/1 - 0s - loss: 2.5814 - mse: 2.5814 - val_loss: 5.4860 - val_mse: 5.4860 - 184ms/epoch - 184ms/step
# Epoch 1803/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4811 - val_mse: 5.4811 - 181ms/epoch - 181ms/step
# Epoch 1804/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4859 - val_mse: 5.4859 - 164ms/epoch - 164ms/step
# Epoch 1805/4000
# 1/1 - 0s - loss: 2.5811 - mse: 2.5811 - val_loss: 5.4809 - val_mse: 5.4809 - 179ms/epoch - 179ms/step
# Epoch 1806/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4857 - val_mse: 5.4857 - 162ms/epoch - 162ms/step
# Epoch 1807/4000
# 1/1 - 0s - loss: 2.5811 - mse: 2.5811 - val_loss: 5.4808 - val_mse: 5.4808 - 197ms/epoch - 197ms/step
# Epoch 1808/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4856 - val_mse: 5.4856 - 161ms/epoch - 161ms/step
# Epoch 1809/4000
# 1/1 - 0s - loss: 2.5811 - mse: 2.5811 - val_loss: 5.4807 - val_mse: 5.4807 - 198ms/epoch - 198ms/step
# Epoch 1810/4000
# 1/1 - 0s - loss: 2.5813 - mse: 2.5813 - val_loss: 5.4855 - val_mse: 5.4855 - 173ms/epoch - 173ms/step
# Epoch 1811/4000
# 1/1 - 0s - loss: 2.5811 - mse: 2.5811 - val_loss: 5.4806 - val_mse: 5.4806 - 187ms/epoch - 187ms/step
# Epoch 1812/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4854 - val_mse: 5.4854 - 174ms/epoch - 174ms/step
# Epoch 1813/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4804 - val_mse: 5.4804 - 199ms/epoch - 199ms/step
# Epoch 1814/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4852 - val_mse: 5.4852 - 167ms/epoch - 167ms/step
# Epoch 1815/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4803 - val_mse: 5.4803 - 181ms/epoch - 181ms/step
# Epoch 1816/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4851 - val_mse: 5.4851 - 177ms/epoch - 177ms/step
# Epoch 1817/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4802 - val_mse: 5.4802 - 178ms/epoch - 178ms/step
# Epoch 1818/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4850 - val_mse: 5.4850 - 190ms/epoch - 190ms/step
# Epoch 1819/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4801 - val_mse: 5.4801 - 180ms/epoch - 180ms/step
# Epoch 1820/4000
# 1/1 - 0s - loss: 2.5812 - mse: 2.5812 - val_loss: 5.4849 - val_mse: 5.4849 - 187ms/epoch - 187ms/step
# Epoch 1821/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4799 - val_mse: 5.4799 - 192ms/epoch - 192ms/step
# Epoch 1822/4000
# 1/1 - 0s - loss: 2.5811 - mse: 2.5811 - val_loss: 5.4848 - val_mse: 5.4848 - 175ms/epoch - 175ms/step
# Epoch 1823/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4798 - val_mse: 5.4798 - 195ms/epoch - 195ms/step
# Epoch 1824/4000
# 1/1 - 0s - loss: 2.5811 - mse: 2.5811 - val_loss: 5.4847 - val_mse: 5.4847 - 175ms/epoch - 175ms/step
# Epoch 1825/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4797 - val_mse: 5.4797 - 190ms/epoch - 190ms/step
# Epoch 1826/4000
# 1/1 - 0s - loss: 2.5811 - mse: 2.5811 - val_loss: 5.4845 - val_mse: 5.4845 - 177ms/epoch - 177ms/step
# Epoch 1827/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4796 - val_mse: 5.4796 - 184ms/epoch - 184ms/step
# Epoch 1828/4000
# 1/1 - 0s - loss: 2.5811 - mse: 2.5811 - val_loss: 5.4844 - val_mse: 5.4844 - 167ms/epoch - 167ms/step
# Epoch 1829/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4794 - val_mse: 5.4794 - 206ms/epoch - 206ms/step
# Epoch 1830/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4843 - val_mse: 5.4843 - 171ms/epoch - 171ms/step
# Epoch 1831/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4793 - val_mse: 5.4793 - 190ms/epoch - 190ms/step
# Epoch 1832/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4842 - val_mse: 5.4842 - 173ms/epoch - 173ms/step
# Epoch 1833/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4792 - val_mse: 5.4792 - 185ms/epoch - 185ms/step
# Epoch 1834/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4841 - val_mse: 5.4841 - 185ms/epoch - 185ms/step
# Epoch 1835/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4791 - val_mse: 5.4791 - 207ms/epoch - 207ms/step
# Epoch 1836/4000
# 1/1 - 0s - loss: 2.5810 - mse: 2.5810 - val_loss: 5.4839 - val_mse: 5.4839 - 168ms/epoch - 168ms/step
# Epoch 1837/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4790 - val_mse: 5.4790 - 185ms/epoch - 185ms/step
# Epoch 1838/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4838 - val_mse: 5.4838 - 220ms/epoch - 220ms/step
# Epoch 1839/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4788 - val_mse: 5.4788 - 215ms/epoch - 215ms/step
# Epoch 1840/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4837 - val_mse: 5.4837 - 170ms/epoch - 170ms/step
# Epoch 1841/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4787 - val_mse: 5.4787 - 190ms/epoch - 190ms/step
# Epoch 1842/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4836 - val_mse: 5.4836 - 176ms/epoch - 176ms/step
# Epoch 1843/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4786 - val_mse: 5.4786 - 190ms/epoch - 190ms/step
# Epoch 1844/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4835 - val_mse: 5.4835 - 171ms/epoch - 171ms/step
# Epoch 1845/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4785 - val_mse: 5.4785 - 176ms/epoch - 176ms/step
# Epoch 1846/4000
# 1/1 - 0s - loss: 2.5809 - mse: 2.5809 - val_loss: 5.4834 - val_mse: 5.4834 - 170ms/epoch - 170ms/step
# Epoch 1847/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4783 - val_mse: 5.4783 - 177ms/epoch - 177ms/step
# Epoch 1848/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4833 - val_mse: 5.4833 - 168ms/epoch - 168ms/step
# Epoch 1849/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4782 - val_mse: 5.4782 - 198ms/epoch - 198ms/step
# Epoch 1850/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4831 - val_mse: 5.4831 - 200ms/epoch - 200ms/step
# Epoch 1851/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4781 - val_mse: 5.4781 - 188ms/epoch - 188ms/step
# Epoch 1852/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4830 - val_mse: 5.4830 - 168ms/epoch - 168ms/step
# Epoch 1853/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4780 - val_mse: 5.4780 - 193ms/epoch - 193ms/step
# Epoch 1854/4000
# 1/1 - 0s - loss: 2.5808 - mse: 2.5808 - val_loss: 5.4829 - val_mse: 5.4829 - 166ms/epoch - 166ms/step
# Epoch 1855/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4779 - val_mse: 5.4779 - 198ms/epoch - 198ms/step
# Epoch 1856/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4828 - val_mse: 5.4828 - 167ms/epoch - 167ms/step
# Epoch 1857/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4778 - val_mse: 5.4778 - 195ms/epoch - 195ms/step
# Epoch 1858/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4827 - val_mse: 5.4827 - 167ms/epoch - 167ms/step
# Epoch 1859/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4776 - val_mse: 5.4776 - 185ms/epoch - 185ms/step
# Epoch 1860/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4826 - val_mse: 5.4826 - 185ms/epoch - 185ms/step
# Epoch 1861/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4775 - val_mse: 5.4775 - 182ms/epoch - 182ms/step
# Epoch 1862/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4825 - val_mse: 5.4825 - 181ms/epoch - 181ms/step
# Epoch 1863/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4774 - val_mse: 5.4774 - 177ms/epoch - 177ms/step
# Epoch 1864/4000
# 1/1 - 0s - loss: 2.5807 - mse: 2.5807 - val_loss: 5.4823 - val_mse: 5.4823 - 163ms/epoch - 163ms/step
# Epoch 1865/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4773 - val_mse: 5.4773 - 179ms/epoch - 179ms/step
# Epoch 1866/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4822 - val_mse: 5.4822 - 171ms/epoch - 171ms/step
# Epoch 1867/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4772 - val_mse: 5.4772 - 175ms/epoch - 175ms/step
# Epoch 1868/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4821 - val_mse: 5.4821 - 179ms/epoch - 179ms/step
# Epoch 1869/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4770 - val_mse: 5.4770 - 186ms/epoch - 186ms/step
# Epoch 1870/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4820 - val_mse: 5.4820 - 178ms/epoch - 178ms/step
# Epoch 1871/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4769 - val_mse: 5.4769 - 210ms/epoch - 210ms/step
# Epoch 1872/4000
# 1/1 - 0s - loss: 2.5806 - mse: 2.5806 - val_loss: 5.4819 - val_mse: 5.4819 - 186ms/epoch - 186ms/step
# Epoch 1873/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4768 - val_mse: 5.4768 - 191ms/epoch - 191ms/step
# Epoch 1874/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4818 - val_mse: 5.4818 - 172ms/epoch - 172ms/step
# Epoch 1875/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4767 - val_mse: 5.4767 - 182ms/epoch - 182ms/step
# Epoch 1876/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4817 - val_mse: 5.4817 - 192ms/epoch - 192ms/step
# Epoch 1877/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4766 - val_mse: 5.4766 - 183ms/epoch - 183ms/step
# Epoch 1878/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4816 - val_mse: 5.4816 - 171ms/epoch - 171ms/step
# Epoch 1879/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4765 - val_mse: 5.4765 - 181ms/epoch - 181ms/step
# Epoch 1880/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4815 - val_mse: 5.4815 - 162ms/epoch - 162ms/step
# Epoch 1881/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4764 - val_mse: 5.4764 - 176ms/epoch - 176ms/step
# Epoch 1882/4000
# 1/1 - 0s - loss: 2.5805 - mse: 2.5805 - val_loss: 5.4813 - val_mse: 5.4813 - 185ms/epoch - 185ms/step
# Epoch 1883/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4762 - val_mse: 5.4762 - 184ms/epoch - 184ms/step
# Epoch 1884/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4812 - val_mse: 5.4812 - 179ms/epoch - 179ms/step
# Epoch 1885/4000
# 1/1 - 0s - loss: 2.5802 - mse: 2.5802 - val_loss: 5.4761 - val_mse: 5.4761 - 187ms/epoch - 187ms/step
# Epoch 1886/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4811 - val_mse: 5.4811 - 166ms/epoch - 166ms/step
# Epoch 1887/4000
# 1/1 - 0s - loss: 2.5802 - mse: 2.5802 - val_loss: 5.4760 - val_mse: 5.4760 - 210ms/epoch - 210ms/step
# Epoch 1888/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4810 - val_mse: 5.4810 - 189ms/epoch - 189ms/step
# Epoch 1889/4000
# 1/1 - 0s - loss: 2.5802 - mse: 2.5802 - val_loss: 5.4759 - val_mse: 5.4759 - 184ms/epoch - 184ms/step
# Epoch 1890/4000
# 1/1 - 0s - loss: 2.5804 - mse: 2.5804 - val_loss: 5.4809 - val_mse: 5.4809 - 180ms/epoch - 180ms/step
# Epoch 1891/4000
# 1/1 - 0s - loss: 2.5802 - mse: 2.5802 - val_loss: 5.4758 - val_mse: 5.4758 - 187ms/epoch - 187ms/step
# Epoch 1892/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4808 - val_mse: 5.4808 - 159ms/epoch - 159ms/step
# Epoch 1893/4000
# 1/1 - 0s - loss: 2.5801 - mse: 2.5801 - val_loss: 5.4757 - val_mse: 5.4757 - 199ms/epoch - 199ms/step
# Epoch 1894/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4807 - val_mse: 5.4807 - 173ms/epoch - 173ms/step
# Epoch 1895/4000
# 1/1 - 0s - loss: 2.5801 - mse: 2.5801 - val_loss: 5.4756 - val_mse: 5.4756 - 179ms/epoch - 179ms/step
# Epoch 1896/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4806 - val_mse: 5.4806 - 158ms/epoch - 158ms/step
# Epoch 1897/4000
# 1/1 - 0s - loss: 2.5801 - mse: 2.5801 - val_loss: 5.4754 - val_mse: 5.4754 - 180ms/epoch - 180ms/step
# Epoch 1898/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4805 - val_mse: 5.4805 - 188ms/epoch - 188ms/step
# Epoch 1899/4000
# 1/1 - 0s - loss: 2.5801 - mse: 2.5801 - val_loss: 5.4753 - val_mse: 5.4753 - 187ms/epoch - 187ms/step
# Epoch 1900/4000
# 1/1 - 0s - loss: 2.5803 - mse: 2.5803 - val_loss: 5.4804 - val_mse: 5.4804 - 171ms/epoch - 171ms/step
# Epoch 1901/4000
# 1/1 - 0s - loss: 2.5801 - mse: 2.5801 - val_loss: 5.4752 - val_mse: 5.4752 - 191ms/epoch - 191ms/step
# Epoch 1902/4000
# 1/1 - 0s - loss: 2.5802 - mse: 2.5802 - val_loss: 5.4803 - val_mse: 5.4803 - 186ms/epoch - 186ms/step
# Epoch 1903/4000
# 1/1 - 0s - loss: 2.5800 - mse: 2.5800 - val_loss: 5.4751 - val_mse: 5.4751 - 192ms/epoch - 192ms/step
# Epoch 1904/4000
# 1/1 - 0s - loss: 2.5802 - mse: 2.5802 - val_loss: 5.4802 - val_mse: 5.4802 - 182ms/epoch - 182ms/step
# Epoch 1905/4000
# 1/1 - 0s - loss: 2.5800 - mse: 2.5800 - val_loss: 5.4750 - val_mse: 5.4750 - 188ms/epoch - 188ms/step
# Epoch 1906/4000
# 1/1 - 0s - loss: 2.5802 - mse: 2.5802 - val_loss: 5.4801 - val_mse: 5.4801 - 180ms/epoch - 180ms/step
# Epoch 1907/4000
# ...
# Epoch 3866/4000
# 1/1 - 0s - loss: 2.5571 - mse: 2.5571 - val_loss: 5.5228 - val_mse: 5.5228 - 171ms/epoch - 171ms/step
# Epoch 3867/4000
# 1/1 - 0s - loss: 2.5569 - mse: 2.5569 - val_loss: 5.5093 - val_mse: 5.5093 - 180ms/epoch - 180ms/step
# Epoch 3868/4000
# 1/1 - 0s - loss: 2.5571 - mse: 2.5571 - val_loss: 5.5230 - val_mse: 5.5230 - 173ms/epoch - 173ms/step
# Epoch 3869/4000
# 1/1 - 0s - loss: 2.5569 - mse: 2.5569 - val_loss: 5.5095 - val_mse: 5.5095 - 173ms/epoch - 173ms/step
# Epoch 3870/4000
# 1/1 - 0s - loss: 2.5570 - mse: 2.5570 - val_loss: 5.5232 - val_mse: 5.5232 - 184ms/epoch - 184ms/step
# Epoch 3871/4000
# 1/1 - 0s - loss: 2.5568 - mse: 2.5568 - val_loss: 5.5097 - val_mse: 5.5097 - 155ms/epoch - 155ms/step
# Epoch 3872/4000
# 1/1 - 0s - loss: 2.5570 - mse: 2.5570 - val_loss: 5.5234 - val_mse: 5.5234 - 158ms/epoch - 158ms/step
# Epoch 3873/4000
# 1/1 - 0s - loss: 2.5568 - mse: 2.5568 - val_loss: 5.5099 - val_mse: 5.5099 - 166ms/epoch - 166ms/step
# Epoch 3874/4000
# 1/1 - 0s - loss: 2.5570 - mse: 2.5570 - val_loss: 5.5236 - val_mse: 5.5236 - 170ms/epoch - 170ms/step
# Epoch 3875/4000
# 1/1 - 0s - loss: 2.5568 - mse: 2.5568 - val_loss: 5.5101 - val_mse: 5.5101 - 170ms/epoch - 170ms/step
# Epoch 3876/4000
# 1/1 - 0s - loss: 2.5570 - mse: 2.5570 - val_loss: 5.5238 - val_mse: 5.5238 - 163ms/epoch - 163ms/step
# Epoch 3877/4000
# 1/1 - 0s - loss: 2.5568 - mse: 2.5568 - val_loss: 5.5103 - val_mse: 5.5103 - 179ms/epoch - 179ms/step
# Epoch 3878/4000
# 1/1 - 0s - loss: 2.5569 - mse: 2.5569 - val_loss: 5.5240 - val_mse: 5.5240 - 168ms/epoch - 168ms/step
# Epoch 3879/4000
# 1/1 - 0s - loss: 2.5567 - mse: 2.5567 - val_loss: 5.5104 - val_mse: 5.5104 - 176ms/epoch - 176ms/step
# Epoch 3880/4000
# 1/1 - 0s - loss: 2.5569 - mse: 2.5569 - val_loss: 5.5242 - val_mse: 5.5242 - 166ms/epoch - 166ms/step
# Epoch 3881/4000
# 1/1 - 0s - loss: 2.5567 - mse: 2.5567 - val_loss: 5.5106 - val_mse: 5.5106 - 177ms/epoch - 177ms/step
# Epoch 3882/4000
# 1/1 - 0s - loss: 2.5569 - mse: 2.5569 - val_loss: 5.5244 - val_mse: 5.5244 - 164ms/epoch - 164ms/step
# Epoch 3883/4000
# 1/1 - 0s - loss: 2.5567 - mse: 2.5567 - val_loss: 5.5108 - val_mse: 5.5108 - 162ms/epoch - 162ms/step
# Epoch 3884/4000
# 1/1 - 0s - loss: 2.5569 - mse: 2.5569 - val_loss: 5.5246 - val_mse: 5.5246 - 158ms/epoch - 158ms/step
# Epoch 3885/4000
# 1/1 - 0s - loss: 2.5567 - mse: 2.5567 - val_loss: 5.5110 - val_mse: 5.5110 - 171ms/epoch - 171ms/step
# Epoch 3886/4000
# 1/1 - 0s - loss: 2.5568 - mse: 2.5568 - val_loss: 5.5248 - val_mse: 5.5248 - 162ms/epoch - 162ms/step
# Epoch 3887/4000
# 1/1 - 0s - loss: 2.5566 - mse: 2.5566 - val_loss: 5.5112 - val_mse: 5.5112 - 172ms/epoch - 172ms/step
# Epoch 3888/4000
# 1/1 - 0s - loss: 2.5568 - mse: 2.5568 - val_loss: 5.5250 - val_mse: 5.5250 - 180ms/epoch - 180ms/step
# Epoch 3889/4000
# 1/1 - 0s - loss: 2.5566 - mse: 2.5566 - val_loss: 5.5114 - val_mse: 5.5114 - 164ms/epoch - 164ms/step
# Epoch 3890/4000
# 1/1 - 0s - loss: 2.5568 - mse: 2.5568 - val_loss: 5.5252 - val_mse: 5.5252 - 159ms/epoch - 159ms/step
# Epoch 3891/4000
# 1/1 - 0s - loss: 2.5566 - mse: 2.5566 - val_loss: 5.5116 - val_mse: 5.5116 - 157ms/epoch - 157ms/step
# Epoch 3892/4000
# 1/1 - 0s - loss: 2.5568 - mse: 2.5568 - val_loss: 5.5254 - val_mse: 5.5254 - 169ms/epoch - 169ms/step
# Epoch 3893/4000
# 1/1 - 0s - loss: 2.5566 - mse: 2.5566 - val_loss: 5.5118 - val_mse: 5.5118 - 172ms/epoch - 172ms/step
# Epoch 3894/4000
# 1/1 - 0s - loss: 2.5567 - mse: 2.5567 - val_loss: 5.5256 - val_mse: 5.5256 - 157ms/epoch - 157ms/step
# Epoch 3895/4000
# 1/1 - 0s - loss: 2.5565 - mse: 2.5565 - val_loss: 5.5119 - val_mse: 5.5119 - 163ms/epoch - 163ms/step
# Epoch 3896/4000
# 1/1 - 0s - loss: 2.5567 - mse: 2.5567 - val_loss: 5.5258 - val_mse: 5.5258 - 162ms/epoch - 162ms/step
# Epoch 3897/4000
# 1/1 - 0s - loss: 2.5565 - mse: 2.5565 - val_loss: 5.5121 - val_mse: 5.5121 - 162ms/epoch - 162ms/step
# Epoch 3898/4000
# 1/1 - 0s - loss: 2.5567 - mse: 2.5567 - val_loss: 5.5260 - val_mse: 5.5260 - 159ms/epoch - 159ms/step
# Epoch 3899/4000
# 1/1 - 0s - loss: 2.5565 - mse: 2.5565 - val_loss: 5.5123 - val_mse: 5.5123 - 174ms/epoch - 174ms/step
# Epoch 3900/4000
# 1/1 - 0s - loss: 2.5567 - mse: 2.5567 - val_loss: 5.5262 - val_mse: 5.5262 - 169ms/epoch - 169ms/step
# Epoch 3901/4000
# 1/1 - 0s - loss: 2.5565 - mse: 2.5565 - val_loss: 5.5125 - val_mse: 5.5125 - 172ms/epoch - 172ms/step
# Epoch 3902/4000
# 1/1 - 0s - loss: 2.5566 - mse: 2.5566 - val_loss: 5.5264 - val_mse: 5.5264 - 171ms/epoch - 171ms/step
# Epoch 3903/4000
# 1/1 - 0s - loss: 2.5564 - mse: 2.5564 - val_loss: 5.5127 - val_mse: 5.5127 - 164ms/epoch - 164ms/step
# Epoch 3904/4000
# 1/1 - 0s - loss: 2.5566 - mse: 2.5566 - val_loss: 5.5266 - val_mse: 5.5266 - 162ms/epoch - 162ms/step
# Epoch 3905/4000
# 1/1 - 0s - loss: 2.5564 - mse: 2.5564 - val_loss: 5.5129 - val_mse: 5.5129 - 178ms/epoch - 178ms/step
# Epoch 3906/4000
# 1/1 - 0s - loss: 2.5566 - mse: 2.5566 - val_loss: 5.5268 - val_mse: 5.5268 - 162ms/epoch - 162ms/step
# Epoch 3907/4000
# 1/1 - 0s - loss: 2.5564 - mse: 2.5564 - val_loss: 5.5131 - val_mse: 5.5131 - 182ms/epoch - 182ms/step
# Epoch 3908/4000
# 1/1 - 0s - loss: 2.5566 - mse: 2.5566 - val_loss: 5.5270 - val_mse: 5.5270 - 177ms/epoch - 177ms/step
# Epoch 3909/4000
# 1/1 - 0s - loss: 2.5564 - mse: 2.5564 - val_loss: 5.5133 - val_mse: 5.5133 - 156ms/epoch - 156ms/step
# Epoch 3910/4000
# 1/1 - 0s - loss: 2.5565 - mse: 2.5565 - val_loss: 5.5272 - val_mse: 5.5272 - 159ms/epoch - 159ms/step
# Epoch 3911/4000
# 1/1 - 0s - loss: 2.5563 - mse: 2.5563 - val_loss: 5.5135 - val_mse: 5.5135 - 176ms/epoch - 176ms/step
# Epoch 3912/4000
# 1/1 - 0s - loss: 2.5565 - mse: 2.5565 - val_loss: 5.5274 - val_mse: 5.5274 - 176ms/epoch - 176ms/step
# Epoch 3913/4000
# 1/1 - 0s - loss: 2.5563 - mse: 2.5563 - val_loss: 5.5137 - val_mse: 5.5137 - 154ms/epoch - 154ms/step
# Epoch 3914/4000
# 1/1 - 0s - loss: 2.5565 - mse: 2.5565 - val_loss: 5.5276 - val_mse: 5.5276 - 164ms/epoch - 164ms/step
# Epoch 3915/4000
# 1/1 - 0s - loss: 2.5563 - mse: 2.5563 - val_loss: 5.5139 - val_mse: 5.5139 - 161ms/epoch - 161ms/step
# Epoch 3916/4000
# 1/1 - 0s - loss: 2.5565 - mse: 2.5565 - val_loss: 5.5278 - val_mse: 5.5278 - 178ms/epoch - 178ms/step
# Epoch 3917/4000
# 1/1 - 0s - loss: 2.5563 - mse: 2.5563 - val_loss: 5.5140 - val_mse: 5.5140 - 171ms/epoch - 171ms/step
# Epoch 3918/4000
# 1/1 - 0s - loss: 2.5564 - mse: 2.5564 - val_loss: 5.5280 - val_mse: 5.5280 - 178ms/epoch - 178ms/step
# Epoch 3919/4000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.5142 - val_mse: 5.5142 - 174ms/epoch - 174ms/step
# Epoch 3920/4000
# 1/1 - 0s - loss: 2.5564 - mse: 2.5564 - val_loss: 5.5282 - val_mse: 5.5282 - 172ms/epoch - 172ms/step
# Epoch 3921/4000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.5144 - val_mse: 5.5144 - 157ms/epoch - 157ms/step
# Epoch 3922/4000
# 1/1 - 0s - loss: 2.5564 - mse: 2.5564 - val_loss: 5.5285 - val_mse: 5.5285 - 175ms/epoch - 175ms/step
# Epoch 3923/4000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.5146 - val_mse: 5.5146 - 174ms/epoch - 174ms/step
# Epoch 3924/4000
# 1/1 - 0s - loss: 2.5564 - mse: 2.5564 - val_loss: 5.5287 - val_mse: 5.5287 - 168ms/epoch - 168ms/step
# Epoch 3925/4000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.5148 - val_mse: 5.5148 - 162ms/epoch - 162ms/step
# Epoch 3926/4000
# 1/1 - 0s - loss: 2.5563 - mse: 2.5563 - val_loss: 5.5289 - val_mse: 5.5289 - 166ms/epoch - 166ms/step
# Epoch 3927/4000
# 1/1 - 0s - loss: 2.5561 - mse: 2.5561 - val_loss: 5.5150 - val_mse: 5.5150 - 164ms/epoch - 164ms/step
# Epoch 3928/4000
# 1/1 - 0s - loss: 2.5563 - mse: 2.5563 - val_loss: 5.5291 - val_mse: 5.5291 - 182ms/epoch - 182ms/step
# Epoch 3929/4000
# 1/1 - 0s - loss: 2.5561 - mse: 2.5561 - val_loss: 5.5152 - val_mse: 5.5152 - 177ms/epoch - 177ms/step
# Epoch 3930/4000
# 1/1 - 0s - loss: 2.5563 - mse: 2.5563 - val_loss: 5.5293 - val_mse: 5.5293 - 171ms/epoch - 171ms/step
# Epoch 3931/4000
# 1/1 - 0s - loss: 2.5561 - mse: 2.5561 - val_loss: 5.5154 - val_mse: 5.5154 - 160ms/epoch - 160ms/step
# Epoch 3932/4000
# 1/1 - 0s - loss: 2.5563 - mse: 2.5563 - val_loss: 5.5295 - val_mse: 5.5295 - 154ms/epoch - 154ms/step
# Epoch 3933/4000
# 1/1 - 0s - loss: 2.5561 - mse: 2.5561 - val_loss: 5.5156 - val_mse: 5.5156 - 171ms/epoch - 171ms/step
# Epoch 3934/4000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.5297 - val_mse: 5.5297 - 161ms/epoch - 161ms/step
# Epoch 3935/4000
# 1/1 - 0s - loss: 2.5560 - mse: 2.5560 - val_loss: 5.5158 - val_mse: 5.5158 - 163ms/epoch - 163ms/step
# Epoch 3936/4000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.5299 - val_mse: 5.5299 - 165ms/epoch - 165ms/step
# Epoch 3937/4000
# 1/1 - 0s - loss: 2.5560 - mse: 2.5560 - val_loss: 5.5160 - val_mse: 5.5160 - 162ms/epoch - 162ms/step
# Epoch 3938/4000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.5301 - val_mse: 5.5301 - 162ms/epoch - 162ms/step
# Epoch 3939/4000
# 1/1 - 0s - loss: 2.5560 - mse: 2.5560 - val_loss: 5.5162 - val_mse: 5.5162 - 174ms/epoch - 174ms/step
# Epoch 3940/4000
# 1/1 - 0s - loss: 2.5562 - mse: 2.5562 - val_loss: 5.5303 - val_mse: 5.5303 - 167ms/epoch - 167ms/step
# Epoch 3941/4000
# 1/1 - 0s - loss: 2.5560 - mse: 2.5560 - val_loss: 5.5164 - val_mse: 5.5164 - 167ms/epoch - 167ms/step
# Epoch 3942/4000
# 1/1 - 0s - loss: 2.5561 - mse: 2.5561 - val_loss: 5.5305 - val_mse: 5.5305 - 156ms/epoch - 156ms/step
# Epoch 3943/4000
# 1/1 - 0s - loss: 2.5559 - mse: 2.5559 - val_loss: 5.5166 - val_mse: 5.5166 - 166ms/epoch - 166ms/step
# Epoch 3944/4000
# 1/1 - 0s - loss: 2.5561 - mse: 2.5561 - val_loss: 5.5307 - val_mse: 5.5307 - 163ms/epoch - 163ms/step
# Epoch 3945/4000
# 1/1 - 0s - loss: 2.5559 - mse: 2.5559 - val_loss: 5.5168 - val_mse: 5.5168 - 175ms/epoch - 175ms/step
# Epoch 3946/4000
# 1/1 - 0s - loss: 2.5561 - mse: 2.5561 - val_loss: 5.5309 - val_mse: 5.5309 - 164ms/epoch - 164ms/step
# Epoch 3947/4000
# 1/1 - 0s - loss: 2.5559 - mse: 2.5559 - val_loss: 5.5170 - val_mse: 5.5170 - 152ms/epoch - 152ms/step
# Epoch 3948/4000
# 1/1 - 0s - loss: 2.5561 - mse: 2.5561 - val_loss: 5.5312 - val_mse: 5.5312 - 162ms/epoch - 162ms/step
# Epoch 3949/4000
# 1/1 - 0s - loss: 2.5559 - mse: 2.5559 - val_loss: 5.5172 - val_mse: 5.5172 - 160ms/epoch - 160ms/step
# Epoch 3950/4000
# 1/1 - 0s - loss: 2.5560 - mse: 2.5560 - val_loss: 5.5314 - val_mse: 5.5314 - 164ms/epoch - 164ms/step
# Epoch 3951/4000
# 1/1 - 0s - loss: 2.5558 - mse: 2.5558 - val_loss: 5.5174 - val_mse: 5.5174 - 170ms/epoch - 170ms/step
# Epoch 3952/4000
# 1/1 - 0s - loss: 2.5560 - mse: 2.5560 - val_loss: 5.5316 - val_mse: 5.5316 - 159ms/epoch - 159ms/step
# Epoch 3953/4000
# 1/1 - 0s - loss: 2.5558 - mse: 2.5558 - val_loss: 5.5176 - val_mse: 5.5176 - 166ms/epoch - 166ms/step
# Epoch 3954/4000
# 1/1 - 0s - loss: 2.5560 - mse: 2.5560 - val_loss: 5.5318 - val_mse: 5.5318 - 165ms/epoch - 165ms/step
# Epoch 3955/4000
# 1/1 - 0s - loss: 2.5558 - mse: 2.5558 - val_loss: 5.5178 - val_mse: 5.5178 - 163ms/epoch - 163ms/step
# Epoch 3956/4000
# 1/1 - 0s - loss: 2.5560 - mse: 2.5560 - val_loss: 5.5320 - val_mse: 5.5320 - 175ms/epoch - 175ms/step
# Epoch 3957/4000
# 1/1 - 0s - loss: 2.5558 - mse: 2.5558 - val_loss: 5.5180 - val_mse: 5.5180 - 169ms/epoch - 169ms/step
# Epoch 3958/4000
# 1/1 - 0s - loss: 2.5559 - mse: 2.5559 - val_loss: 5.5322 - val_mse: 5.5322 - 166ms/epoch - 166ms/step
# Epoch 3959/4000
# 1/1 - 0s - loss: 2.5557 - mse: 2.5557 - val_loss: 5.5182 - val_mse: 5.5182 - 166ms/epoch - 166ms/step
# Epoch 3960/4000
# 1/1 - 0s - loss: 2.5559 - mse: 2.5559 - val_loss: 5.5324 - val_mse: 5.5324 - 163ms/epoch - 163ms/step
# Epoch 3961/4000
# 1/1 - 0s - loss: 2.5557 - mse: 2.5557 - val_loss: 5.5184 - val_mse: 5.5184 - 168ms/epoch - 168ms/step
# Epoch 3962/4000
# 1/1 - 0s - loss: 2.5559 - mse: 2.5559 - val_loss: 5.5326 - val_mse: 5.5326 - 176ms/epoch - 176ms/step
# Epoch 3963/4000
# 1/1 - 0s - loss: 2.5557 - mse: 2.5557 - val_loss: 5.5186 - val_mse: 5.5186 - 161ms/epoch - 161ms/step
# Epoch 3964/4000
# 1/1 - 0s - loss: 2.5559 - mse: 2.5559 - val_loss: 5.5328 - val_mse: 5.5328 - 162ms/epoch - 162ms/step
# Epoch 3965/4000
# 1/1 - 0s - loss: 2.5557 - mse: 2.5557 - val_loss: 5.5188 - val_mse: 5.5188 - 179ms/epoch - 179ms/step
# Epoch 3966/4000
# 1/1 - 0s - loss: 2.5558 - mse: 2.5558 - val_loss: 5.5331 - val_mse: 5.5331 - 174ms/epoch - 174ms/step
# Epoch 3967/4000
# 1/1 - 0s - loss: 2.5556 - mse: 2.5556 - val_loss: 5.5190 - val_mse: 5.5190 - 150ms/epoch - 150ms/step
# Epoch 3968/4000
# 1/1 - 0s - loss: 2.5558 - mse: 2.5558 - val_loss: 5.5333 - val_mse: 5.5333 - 166ms/epoch - 166ms/step
# Epoch 3969/4000
# 1/1 - 0s - loss: 2.5556 - mse: 2.5556 - val_loss: 5.5192 - val_mse: 5.5192 - 159ms/epoch - 159ms/step
# Epoch 3970/4000
# 1/1 - 0s - loss: 2.5558 - mse: 2.5558 - val_loss: 5.5335 - val_mse: 5.5335 - 160ms/epoch - 160ms/step
# Epoch 3971/4000
# 1/1 - 0s - loss: 2.5556 - mse: 2.5556 - val_loss: 5.5194 - val_mse: 5.5194 - 161ms/epoch - 161ms/step
# Epoch 3972/4000
# 1/1 - 0s - loss: 2.5558 - mse: 2.5558 - val_loss: 5.5337 - val_mse: 5.5337 - 160ms/epoch - 160ms/step
# Epoch 3973/4000
# 1/1 - 0s - loss: 2.5556 - mse: 2.5556 - val_loss: 5.5196 - val_mse: 5.5196 - 161ms/epoch - 161ms/step
# Epoch 3974/4000
# 1/1 - 0s - loss: 2.5557 - mse: 2.5557 - val_loss: 5.5339 - val_mse: 5.5339 - 173ms/epoch - 173ms/step
# Epoch 3975/4000
# 1/1 - 0s - loss: 2.5555 - mse: 2.5555 - val_loss: 5.5198 - val_mse: 5.5198 - 168ms/epoch - 168ms/step
# Epoch 3976/4000
# 1/1 - 0s - loss: 2.5557 - mse: 2.5557 - val_loss: 5.5341 - val_mse: 5.5341 - 165ms/epoch - 165ms/step
# Epoch 3977/4000
# 1/1 - 0s - loss: 2.5555 - mse: 2.5555 - val_loss: 5.5200 - val_mse: 5.5200 - 178ms/epoch - 178ms/step
# Epoch 3978/4000
# 1/1 - 0s - loss: 2.5557 - mse: 2.5557 - val_loss: 5.5343 - val_mse: 5.5343 - 159ms/epoch - 159ms/step
# Epoch 3979/4000
# 1/1 - 0s - loss: 2.5555 - mse: 2.5555 - val_loss: 5.5202 - val_mse: 5.5202 - 168ms/epoch - 168ms/step
# Epoch 3980/4000
# 1/1 - 0s - loss: 2.5557 - mse: 2.5557 - val_loss: 5.5346 - val_mse: 5.5346 - 165ms/epoch - 165ms/step
# Epoch 3981/4000
# 1/1 - 0s - loss: 2.5554 - mse: 2.5554 - val_loss: 5.5204 - val_mse: 5.5204 - 156ms/epoch - 156ms/step
# Epoch 3982/4000
# 1/1 - 0s - loss: 2.5556 - mse: 2.5556 - val_loss: 5.5348 - val_mse: 5.5348 - 168ms/epoch - 168ms/step
# Epoch 3983/4000
# 1/1 - 0s - loss: 2.5554 - mse: 2.5554 - val_loss: 5.5206 - val_mse: 5.5206 - 160ms/epoch - 160ms/step
# Epoch 3984/4000
# 1/1 - 0s - loss: 2.5556 - mse: 2.5556 - val_loss: 5.5350 - val_mse: 5.5350 - 167ms/epoch - 167ms/step
# Epoch 3985/4000
# 1/1 - 0s - loss: 2.5554 - mse: 2.5554 - val_loss: 5.5208 - val_mse: 5.5208 - 162ms/epoch - 162ms/step
# Epoch 3986/4000
# 1/1 - 0s - loss: 2.5556 - mse: 2.5556 - val_loss: 5.5352 - val_mse: 5.5352 - 182ms/epoch - 182ms/step
# Epoch 3987/4000
# 1/1 - 0s - loss: 2.5554 - mse: 2.5554 - val_loss: 5.5210 - val_mse: 5.5210 - 163ms/epoch - 163ms/step
# Epoch 3988/4000
# 1/1 - 0s - loss: 2.5556 - mse: 2.5556 - val_loss: 5.5354 - val_mse: 5.5354 - 170ms/epoch - 170ms/step
# Epoch 3989/4000
# 1/1 - 0s - loss: 2.5553 - mse: 2.5553 - val_loss: 5.5212 - val_mse: 5.5212 - 173ms/epoch - 173ms/step
# Epoch 3990/4000
# 1/1 - 0s - loss: 2.5555 - mse: 2.5555 - val_loss: 5.5356 - val_mse: 5.5356 - 171ms/epoch - 171ms/step
# Epoch 3991/4000
# 1/1 - 0s - loss: 2.5553 - mse: 2.5553 - val_loss: 5.5214 - val_mse: 5.5214 - 170ms/epoch - 170ms/step
# Epoch 3992/4000
# 1/1 - 0s - loss: 2.5555 - mse: 2.5555 - val_loss: 5.5359 - val_mse: 5.5359 - 166ms/epoch - 166ms/step
# Epoch 3993/4000
# 1/1 - 0s - loss: 2.5553 - mse: 2.5553 - val_loss: 5.5216 - val_mse: 5.5216 - 159ms/epoch - 159ms/step
# Epoch 3994/4000
# 1/1 - 0s - loss: 2.5555 - mse: 2.5555 - val_loss: 5.5361 - val_mse: 5.5361 - 158ms/epoch - 158ms/step
# Epoch 3995/4000
# 1/1 - 0s - loss: 2.5553 - mse: 2.5553 - val_loss: 5.5218 - val_mse: 5.5218 - 167ms/epoch - 167ms/step
# Epoch 3996/4000
# 1/1 - 0s - loss: 2.5555 - mse: 2.5555 - val_loss: 5.5363 - val_mse: 5.5363 - 165ms/epoch - 165ms/step
# Epoch 3997/4000
# 1/1 - 0s - loss: 2.5552 - mse: 2.5552 - val_loss: 5.5220 - val_mse: 5.5220 - 181ms/epoch - 181ms/step
# Epoch 3998/4000
# 1/1 - 0s - loss: 2.5554 - mse: 2.5554 - val_loss: 5.5365 - val_mse: 5.5365 - 161ms/epoch - 161ms/step
# Epoch 3999/4000
# 1/1 - 0s - loss: 2.5552 - mse: 2.5552 - val_loss: 5.5222 - val_mse: 5.5222 - 159ms/epoch - 159ms/step
# Epoch 4000/4000
# 1/1 - 0s - loss: 2.5554 - mse: 2.5554 - val_loss: 5.5367 - val_mse: 5.5367 - 200ms/epoch - 200ms/step
